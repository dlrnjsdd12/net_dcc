# %%
# %pip install pandas

# %% [markdown]
# # Loading Library

# %%
# 기본라이브러리 import
#from google.colab import drive
#import os, json, pickle
#import re

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split

#from sklearn.metrics import confusion_matrix, plot_confusion_matrix
from sklearn.metrics import confusion_matrix
#from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay

# 파이토치 라이브러리 import
import torch
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torch.utils.data import random_split

#Keras Import
import tensorflow as tf
from tensorflow.keras import layers
from datetime import timedelta, datetime

# 데이터 정규화
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_validate
from sklearn.model_selection import GridSearchCV

import warnings
warnings.filterwarnings(action='ignore')

import ipaddress

# 구글 드라이브 mount
#drive.mount('/content/gdrive')

# 데이터 파일 위치
#C:\Users\mariu\내 드라이브\Colab Notebooks\Network
colab_path = '/home/marius1406/'
colab_write_path = "/home/marius1406/"
# Out:
# 2023-10-12 20:40:30.994017: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # Load Data

# %%
colab_path = "/home/marius1406/"
df = pd.read_csv(colab_path+"NF-UQ-NIDS-total.csv",index_col=False, nrows=3000000)
#df = pd.read_csv(colab_path+"NF-UQ-NIDS-total.csv",index_col=False)

# %%
# 확장판에서 사용
#cols = df.columns.drop(['IPV4_SRC_ADDR', 'L4_SRC_PORT', 'IPV4_DST_ADDR', 'L4_DST_PORT', 'PROTOCOL', 'L7_PROTO', 'DNS_QUERY_ID','Label','Attack','Dataset'])  #명목형변수, 레이블 변수 제외
#cols = df.columns.drop(['IPV4_SRC_ADDR_1','IPV4_SRC_ADDR_2','Label','Attack','Dataset', 'Label_1','Attack_1','Dataset_1', 'Label_2','Attack_2','Dataset_2'])  #명목형변수, 레이블 변수 제외
cols = df.columns.drop(['Label','Attack'])  #명목형변수, 레이블 변수 제외#cols = df.columns.drop(['Attack','Dataset'])  #명목형변수, 레이블 변수 제외
X = df[cols]
dummies = pd.get_dummies(df['Attack']) # Classification
outcomes = dummies.columns
num_classes = len(outcomes)
Y = dummies.values

#==================
dummiesLabel = pd.get_dummies(df['Label']) # Classification
y_1_label = df['Label'].values
y_label = dummiesLabel.values

#import pandas as pd
#import numpy as np

def extend_sparse(val):
    if val in ['Analysis', 'Exploits', 'Fuzzers', 'Shellcode', 'Theft', 'Worms', 'mitm']: return 1
    return 0

y_1_attack = pd.DataFrame(df['Attack'])

is_sparse = y_1_attack.applymap(extend_sparse)
y_1_enforce = is_sparse.values
y_enforce = pd.get_dummies(is_sparse['Attack']) # Classification

#=======================

def max_8G(val):
    if (val > 1.0e+9): return 1.0e+9
    return val

#cols =['DST_TO_SRC_SECOND_BYTES', 'SRC_TO_DST_SECOND_BYTES', 'SRC_TO_DST_AVG_THROUGHPUT', 'DST_TO_SRC_AVG_THROUGHPUT']
cols =['DST_TO_SRC_SECOND_BYTES', 'SRC_TO_DST_SECOND_BYTES', 'SRC_TO_DST_AVG_THROUGHPUT', 'DST_TO_SRC_AVG_THROUGHPUT',
'DST_TO_SRC_SECOND_BYTES_1', 'SRC_TO_DST_SECOND_BYTES_1', 'SRC_TO_DST_AVG_THROUGHPUT_1', 'DST_TO_SRC_AVG_THROUGHPUT_1',
'DST_TO_SRC_SECOND_BYTES_2', 'SRC_TO_DST_SECOND_BYTES_2', 'SRC_TO_DST_AVG_THROUGHPUT_2', 'DST_TO_SRC_AVG_THROUGHPUT_2'] 

X[cols] = X[cols].applymap(max_8G)

# %%
for col in X.columns:
    print(col , X[col].max())
# Out:
# IPV4_SRC_ADDR 4294101346
# L4_SRC_PORT 65535
# IPV4_DST_ADDR 4294967295
# L4_DST_PORT 65535
# PROTOCOL 255
# L7_PROTO 248.0
# IN_BYTES 74055365
# IN_PKTS 192610
# OUT_BYTES 155498038
# OUT_PKTS 104565
# TCP_FLAGS 223
# CLIENT_TCP_FLAGS 223
# SERVER_TCP_FLAGS 223
# FLOW_DURATION_MILLISECONDS 4294967
# DURATION_IN 106636
# DURATION_OUT 38547
# MIN_TTL 255
# MAX_TTL 255
# LONGEST_FLOW_PKT 65212
# SHORTEST_FLOW_PKT 1506
# MIN_IP_PKT_LEN 547
# MAX_IP_PKT_LEN 65212
# SRC_TO_DST_SECOND_BYTES 1000000000.0
# DST_TO_SRC_SECOND_BYTES 1000000000.0
# RETRANSMITTED_IN_BYTES 6321251
# RETRANSMITTED_IN_PKTS 12729
# RETRANSMITTED_OUT_BYTES 3953335
# RETRANSMITTED_OUT_PKTS 2909
# SRC_TO_DST_AVG_THROUGHPUT 1000000000.0
# DST_TO_SRC_AVG_THROUGHPUT 1000000000.0
# NUM_PKTS_UP_TO_128_BYTES 192610
# NUM_PKTS_128_TO_256_BYTES 7230
# NUM_PKTS_256_TO_512_BYTES 12730
# NUM_PKTS_512_TO_1024_BYTES 36152
# NUM_PKTS_1024_TO_1514_BYTES 103351
# TCP_WIN_MAX_IN 65535
# TCP_WIN_MAX_OUT 65535
# ICMP_TYPE 65280
# ICMP_IPV4_TYPE 255
# DNS_QUERY_ID 65535
# DNS_QUERY_TYPE 32769
# DNS_TTL_ANSWER 4294915672
# FTP_COMMAND_RET_CODE 553.0
# L4_SRC_PORT_1 65535
# IPV4_DST_ADDR_1 4294967295
# L4_DST_PORT_1 65535
# PROTOCOL_1 255
# L7_PROTO_1 248.0
# IN_BYTES_1 74055365
# IN_PKTS_1 192610
# OUT_BYTES_1 155498038
# OUT_PKTS_1 104565
# TCP_FLAGS_1 223
# CLIENT_TCP_FLAGS_1 223
# SERVER_TCP_FLAGS_1 223
# FLOW_DURATION_MILLISECONDS_1 4294967
# DURATION_IN_1 106636
# DURATION_OUT_1 38547
# MIN_TTL_1 255
# MAX_TTL_1 255
# LONGEST_FLOW_PKT_1 64280
# SHORTEST_FLOW_PKT_1 1504
# MIN_IP_PKT_LEN_1 547
# MAX_IP_PKT_LEN_1 64280
# SRC_TO_DST_SECOND_BYTES_1 1000000000.0
# DST_TO_SRC_SECOND_BYTES_1 1000000000.0
# RETRANSMITTED_IN_BYTES_1 6321251
# RETRANSMITTED_IN_PKTS_1 12729
# RETRANSMITTED_OUT_BYTES_1 3953335
# RETRANSMITTED_OUT_PKTS_1 2909
# SRC_TO_DST_AVG_THROUGHPUT_1 1000000000.0
# DST_TO_SRC_AVG_THROUGHPUT_1 1000000000.0
# NUM_PKTS_UP_TO_128_BYTES_1 192610
# NUM_PKTS_128_TO_256_BYTES_1 7230
# NUM_PKTS_256_TO_512_BYTES_1 12730
# NUM_PKTS_512_TO_1024_BYTES_1 36152
# NUM_PKTS_1024_TO_1514_BYTES_1 103351
# TCP_WIN_MAX_IN_1 65535
# TCP_WIN_MAX_OUT_1 65535
# ICMP_TYPE_1 65280
# ICMP_IPV4_TYPE_1 255
# DNS_QUERY_ID_1 65535
# DNS_QUERY_TYPE_1 32769
# DNS_TTL_ANSWER_1 4294915672
# FTP_COMMAND_RET_CODE_1 553.0
# L4_SRC_PORT_2 65535
# IPV4_DST_ADDR_2 4294967295
# L4_DST_PORT_2 65535
# PROTOCOL_2 255
# L7_PROTO_2 248.0
# IN_BYTES_2 74055365
# IN_PKTS_2 192610
# OUT_BYTES_2 155498038
# OUT_PKTS_2 104565
# TCP_FLAGS_2 223
# CLIENT_TCP_FLAGS_2 223
# SERVER_TCP_FLAGS_2 223
# FLOW_DURATION_MILLISECONDS_2 4294967
# DURATION_IN_2 106636
# DURATION_OUT_2 38547
# MIN_TTL_2 255
# MAX_TTL_2 255
# LONGEST_FLOW_PKT_2 64280
# SHORTEST_FLOW_PKT_2 1506
# MIN_IP_PKT_LEN_2 479
# MAX_IP_PKT_LEN_2 64280
# SRC_TO_DST_SECOND_BYTES_2 1000000000.0
# DST_TO_SRC_SECOND_BYTES_2 1000000000.0
# RETRANSMITTED_IN_BYTES_2 6321251
# RETRANSMITTED_IN_PKTS_2 12079
# RETRANSMITTED_OUT_BYTES_2 3953335
# RETRANSMITTED_OUT_PKTS_2 2909
# SRC_TO_DST_AVG_THROUGHPUT_2 1000000000.0
# DST_TO_SRC_AVG_THROUGHPUT_2 1000000000.0
# NUM_PKTS_UP_TO_128_BYTES_2 192610
# NUM_PKTS_128_TO_256_BYTES_2 7230
# NUM_PKTS_256_TO_512_BYTES_2 12080
# NUM_PKTS_512_TO_1024_BYTES_2 18954
# NUM_PKTS_1024_TO_1514_BYTES_2 103351
# TCP_WIN_MAX_IN_2 65535
# TCP_WIN_MAX_OUT_2 65535
# ICMP_TYPE_2 65280
# ICMP_IPV4_TYPE_2 255
# DNS_QUERY_ID_2 65535
# DNS_QUERY_TYPE_2 32769
# DNS_TTL_ANSWER_2 4294915672
# FTP_COMMAND_RET_CODE_2 553.0

# %% [markdown]
# # Normalize Data

# %%
# 데이터 정규화
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_validate
from sklearn.model_selection import GridSearchCV


scaler_train = preprocessing.StandardScaler()
scaler_train = scaler_train.fit(X)
X = pd.DataFrame(scaler_train.transform(X),index=np.arange(0,X.shape[0],1), columns = X.columns)

# %%
for col in X.columns:
    print(col , X[col].isna().sum())
X.isna().sum().sum()
# Out:
# IPV4_SRC_ADDR 0
# L4_SRC_PORT 0
# IPV4_DST_ADDR 0
# L4_DST_PORT 0
# PROTOCOL 0
# L7_PROTO 0
# IN_BYTES 0
# IN_PKTS 0
# OUT_BYTES 0
# OUT_PKTS 0
# TCP_FLAGS 0
# CLIENT_TCP_FLAGS 0
# SERVER_TCP_FLAGS 0
# FLOW_DURATION_MILLISECONDS 0
# DURATION_IN 0
# DURATION_OUT 0
# MIN_TTL 0
# MAX_TTL 0
# LONGEST_FLOW_PKT 0
# SHORTEST_FLOW_PKT 0
# MIN_IP_PKT_LEN 0
# MAX_IP_PKT_LEN 0
# SRC_TO_DST_SECOND_BYTES 0
# DST_TO_SRC_SECOND_BYTES 0
# RETRANSMITTED_IN_BYTES 0
# RETRANSMITTED_IN_PKTS 0
# RETRANSMITTED_OUT_BYTES 0
# RETRANSMITTED_OUT_PKTS 0
# SRC_TO_DST_AVG_THROUGHPUT 0
# DST_TO_SRC_AVG_THROUGHPUT 0
# NUM_PKTS_UP_TO_128_BYTES 0
# NUM_PKTS_128_TO_256_BYTES 0
# NUM_PKTS_256_TO_512_BYTES 0
# NUM_PKTS_512_TO_1024_BYTES 0
# NUM_PKTS_1024_TO_1514_BYTES 0
# TCP_WIN_MAX_IN 0
# TCP_WIN_MAX_OUT 0
# ICMP_TYPE 0
# ICMP_IPV4_TYPE 0
# DNS_QUERY_ID 0
# DNS_QUERY_TYPE 0
# DNS_TTL_ANSWER 0
# FTP_COMMAND_RET_CODE 0
# L4_SRC_PORT_1 0
# IPV4_DST_ADDR_1 0
# L4_DST_PORT_1 0
# PROTOCOL_1 0
# L7_PROTO_1 0
# IN_BYTES_1 0
# IN_PKTS_1 0
# OUT_BYTES_1 0
# OUT_PKTS_1 0
# TCP_FLAGS_1 0
# CLIENT_TCP_FLAGS_1 0
# SERVER_TCP_FLAGS_1 0
# FLOW_DURATION_MILLISECONDS_1 0
# DURATION_IN_1 0
# DURATION_OUT_1 0
# MIN_TTL_1 0
# MAX_TTL_1 0
# LONGEST_FLOW_PKT_1 0
# SHORTEST_FLOW_PKT_1 0
# MIN_IP_PKT_LEN_1 0
# MAX_IP_PKT_LEN_1 0
# SRC_TO_DST_SECOND_BYTES_1 0
# DST_TO_SRC_SECOND_BYTES_1 0
# RETRANSMITTED_IN_BYTES_1 0
# RETRANSMITTED_IN_PKTS_1 0
# RETRANSMITTED_OUT_BYTES_1 0
# RETRANSMITTED_OUT_PKTS_1 0
# SRC_TO_DST_AVG_THROUGHPUT_1 0
# DST_TO_SRC_AVG_THROUGHPUT_1 0
# NUM_PKTS_UP_TO_128_BYTES_1 0
# NUM_PKTS_128_TO_256_BYTES_1 0
# NUM_PKTS_256_TO_512_BYTES_1 0
# NUM_PKTS_512_TO_1024_BYTES_1 0
# NUM_PKTS_1024_TO_1514_BYTES_1 0
# TCP_WIN_MAX_IN_1 0
# TCP_WIN_MAX_OUT_1 0
# ICMP_TYPE_1 0
# ICMP_IPV4_TYPE_1 0
# DNS_QUERY_ID_1 0
# DNS_QUERY_TYPE_1 0
# DNS_TTL_ANSWER_1 0
# FTP_COMMAND_RET_CODE_1 0
# L4_SRC_PORT_2 0
# IPV4_DST_ADDR_2 0
# L4_DST_PORT_2 0
# PROTOCOL_2 0
# L7_PROTO_2 0
# IN_BYTES_2 0
# IN_PKTS_2 0
# OUT_BYTES_2 0
# OUT_PKTS_2 0
# TCP_FLAGS_2 0
# CLIENT_TCP_FLAGS_2 0
# SERVER_TCP_FLAGS_2 0
# FLOW_DURATION_MILLISECONDS_2 0
# DURATION_IN_2 0
# DURATION_OUT_2 0
# MIN_TTL_2 0
# MAX_TTL_2 0
# LONGEST_FLOW_PKT_2 0
# SHORTEST_FLOW_PKT_2 0
# MIN_IP_PKT_LEN_2 0
# MAX_IP_PKT_LEN_2 0
# SRC_TO_DST_SECOND_BYTES_2 0
# DST_TO_SRC_SECOND_BYTES_2 0
# RETRANSMITTED_IN_BYTES_2 0
# RETRANSMITTED_IN_PKTS_2 0
# RETRANSMITTED_OUT_BYTES_2 0
# RETRANSMITTED_OUT_PKTS_2 0
# SRC_TO_DST_AVG_THROUGHPUT_2 0
# DST_TO_SRC_AVG_THROUGHPUT_2 0
# NUM_PKTS_UP_TO_128_BYTES_2 0
# NUM_PKTS_128_TO_256_BYTES_2 0
# NUM_PKTS_256_TO_512_BYTES_2 0
# NUM_PKTS_512_TO_1024_BYTES_2 0
# NUM_PKTS_1024_TO_1514_BYTES_2 0
# TCP_WIN_MAX_IN_2 0
# TCP_WIN_MAX_OUT_2 0
# ICMP_TYPE_2 0
# ICMP_IPV4_TYPE_2 0
# DNS_QUERY_ID_2 0
# DNS_QUERY_TYPE_2 0
# DNS_TTL_ANSWER_2 0
# FTP_COMMAND_RET_CODE_2 0
# 0

# %%
def max_3sigma(val):
    if (val < -3): return -3
    if (val > 3): return 3
    return val

X = X.applymap(max_3sigma)

# %%
y1 = tf.argmax(dummies, axis=1)

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.20, shuffle = True, random_state=33)
x_train, x_test_label, y_train_label, y_test_label = train_test_split(X, y_label, test_size=0.20, shuffle = True, random_state=33)
x_train, x_test_enforce, y_train_enforce, y_test_enforce = train_test_split(X, y_enforce, test_size=0.20, shuffle = True, random_state=33)
x_train, x_test_1, y_train_1, y_test_1 = train_test_split(X, y1.numpy(), test_size=0.20, shuffle = True, random_state=33)
# Out:
# 2023-10-12 20:42:14.942317: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.

# %%
from collections import Counter
#type(y_train)
ydp= pd.DataFrame(y_train)
ydp = tf.argmax(ydp, axis=1)
#ydp = pd.DataFrame(ydp)
#ydp.value_counts
dicts = Counter(ydp.numpy())
dicts
# Out:
# Counter({5: 687357,
#          2: 794288,
#          19: 119905,
#          15: 21686,
#          6: 564557,
#          4: 4025,
#          11: 82731,
#          20: 77617,
#          17: 36205,
#          3: 4569,
#          10: 3752,
#          9: 542,
#          7: 968,
#          8: 694,
#          1: 575,
#          16: 239,
#          0: 81,
#          18: 94,
#          13: 69,
#          12: 42,
#          14: 4})

# %% [markdown]
# # Model Train

# %%
colab_write_path = "/home/marius1406/"
colab_model_write_path = colab_write_path + datetime.now().strftime("%Y%m%d%H%M" + "/")
print("colab_write_path=" + colab_write_path)
print("colab_model_write_path=" + colab_model_write_path)

# %%
#model1
#initializer = "glorot_uniform"
initializer = tf.keras.initializers.GlorotUniform(seed=33)
constraints = None


model_1 = tf.keras.Sequential([
  tf.keras.layers.Dense(64, input_dim=X.shape[1], kernel_initializer=initializer, bias_initializer="zeros", kernel_constraint=constraints, activation='relu',name='dense_1a'),
  tf.keras.layers.Dense(128, input_dim=X.shape[1], kernel_initializer=initializer, bias_initializer="zeros", kernel_constraint=constraints,activation='relu',name='dense_1b'),
  tf.keras.layers.Dropout(0.3),
  tf.keras.layers.Dense(128, input_dim=X.shape[1], kernel_initializer=initializer, bias_initializer="zeros", kernel_constraint=constraints,activation='relu',name='dense_1c'),
  tf.keras.layers.Dropout(0.3),
  tf.keras.layers.Dense(64, input_dim=X.shape[1], kernel_initializer=initializer, bias_initializer="zeros", kernel_constraint=constraints,activation='relu',name='dense_1d'),
  tf.keras.layers.Dense(Y.shape[1],activation='softmax')
  ])

# %%
#model 1
model_1.compile(loss='categorical_crossentropy',metrics=['accuracy'], optimizer='adam')

log_dir_1 = colab_model_write_path + "model_1" + datetime.now().strftime("%Y%m%d%H%M%S")
print(log_dir_1)
monitor_1 = [
             tf.keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=1e-5, patience=8, verbose=1, mode='auto',restore_best_weights=True),
             tf.keras.callbacks.TensorBoard(log_dir=log_dir_1, histogram_freq=1)
            ]
history_1  = model_1.fit(x_train,y_train,validation_data=(x_test,y_test), verbose=2, batch_size=1024, epochs=100)
model_1.save(colab_model_write_path + 'model1.h5')
# Out:
# /home/marius1406/202310120135/model_120231012014357
# Epoch 1/100
# 2344/2344 - 46s - loss: 0.1026 - accuracy: 0.9730 - val_loss: 0.0856 - val_accuracy: 0.9773 - 46s/epoch - 20ms/step
# Epoch 2/100
# 2344/2344 - 31s - loss: 0.0887 - accuracy: 0.9766 - val_loss: 0.0813 - val_accuracy: 0.9790 - 31s/epoch - 13ms/step
# Epoch 3/100
# 2344/2344 - 34s - loss: 0.0828 - accuracy: 0.9781 - val_loss: 0.0733 - val_accuracy: 0.9801 - 34s/epoch - 15ms/step
# Epoch 4/100
# 2344/2344 - 46s - loss: 0.0795 - accuracy: 0.9788 - val_loss: 0.0717 - val_accuracy: 0.9805 - 46s/epoch - 20ms/step
# Epoch 5/100
# 2344/2344 - 35s - loss: 0.0772 - accuracy: 0.9792 - val_loss: 0.0709 - val_accuracy: 0.9807 - 35s/epoch - 15ms/step
# Epoch 6/100
# 2344/2344 - 45s - loss: 0.0753 - accuracy: 0.9797 - val_loss: 0.0681 - val_accuracy: 0.9814 - 45s/epoch - 19ms/step
# Epoch 7/100
# 2344/2344 - 56s - loss: 0.0742 - accuracy: 0.9799 - val_loss: 0.0674 - val_accuracy: 0.9815 - 56s/epoch - 24ms/step
# Epoch 8/100
# 2344/2344 - 41s - loss: 0.0730 - accuracy: 0.9803 - val_loss: 0.0681 - val_accuracy: 0.9816 - 41s/epoch - 17ms/step
# Epoch 9/100
# 2344/2344 - 46s - loss: 0.0721 - accuracy: 0.9805 - val_loss: 0.0658 - val_accuracy: 0.9823 - 46s/epoch - 19ms/step
# Epoch 10/100
# 2344/2344 - 40s - loss: 0.0711 - accuracy: 0.9807 - val_loss: 0.0652 - val_accuracy: 0.9823 - 40s/epoch - 17ms/step
# Epoch 11/100
# 2344/2344 - 49s - loss: 0.0705 - accuracy: 0.9809 - val_loss: 0.0644 - val_accuracy: 0.9827 - 49s/epoch - 21ms/step
# Epoch 12/100
# 2344/2344 - 38s - loss: 0.0696 - accuracy: 0.9811 - val_loss: 0.0651 - val_accuracy: 0.9822 - 38s/epoch - 16ms/step
# Epoch 13/100
# 2344/2344 - 55s - loss: 0.0692 - accuracy: 0.9812 - val_loss: 0.0639 - val_accuracy: 0.9826 - 55s/epoch - 23ms/step
# Epoch 14/100
# 2344/2344 - 54s - loss: 0.0687 - accuracy: 0.9813 - val_loss: 0.0627 - val_accuracy: 0.9829 - 54s/epoch - 23ms/step
# Epoch 15/100
# 2344/2344 - 71s - loss: 0.0685 - accuracy: 0.9814 - val_loss: 0.0630 - val_accuracy: 0.9828 - 71s/epoch - 30ms/step
# Epoch 16/100
# 2344/2344 - 42s - loss: 0.0678 - accuracy: 0.9816 - val_loss: 0.0622 - val_accuracy: 0.9831 - 42s/epoch - 18ms/step
# Epoch 17/100
# 2344/2344 - 41s - loss: 0.0675 - accuracy: 0.9816 - val_loss: 0.0620 - val_accuracy: 0.9831 - 41s/epoch - 18ms/step
# Epoch 18/100
# 2344/2344 - 38s - loss: 0.0674 - accuracy: 0.9817 - val_loss: 0.0624 - val_accuracy: 0.9831 - 38s/epoch - 16ms/step
# Epoch 19/100
# 2344/2344 - 31s - loss: 0.0670 - accuracy: 0.9818 - val_loss: 0.0617 - val_accuracy: 0.9833 - 31s/epoch - 13ms/step
# Epoch 20/100
# 2344/2344 - 37s - loss: 0.0665 - accuracy: 0.9819 - val_loss: 0.0607 - val_accuracy: 0.9836 - 37s/epoch - 16ms/step
# Epoch 21/100
# 2344/2344 - 45s - loss: 0.0663 - accuracy: 0.9820 - val_loss: 0.0618 - val_accuracy: 0.9835 - 45s/epoch - 19ms/step
# Epoch 22/100
# 2344/2344 - 29s - loss: 0.0661 - accuracy: 0.9821 - val_loss: 0.0612 - val_accuracy: 0.9835 - 29s/epoch - 12ms/step
# Epoch 23/100
# 2344/2344 - 51s - loss: 0.0658 - accuracy: 0.9821 - val_loss: 0.0609 - val_accuracy: 0.9835 - 51s/epoch - 22ms/step
# Epoch 24/100
# 2344/2344 - 42s - loss: 0.0657 - accuracy: 0.9821 - val_loss: 0.0612 - val_accuracy: 0.9834 - 42s/epoch - 18ms/step
# Epoch 25/100
# 2344/2344 - 50s - loss: 0.0654 - accuracy: 0.9822 - val_loss: 0.0602 - val_accuracy: 0.9838 - 50s/epoch - 21ms/step
# Epoch 26/100
# 2344/2344 - 66s - loss: 0.0653 - accuracy: 0.9823 - val_loss: 0.0604 - val_accuracy: 0.9837 - 66s/epoch - 28ms/step
# Epoch 27/100
# 2344/2344 - 42s - loss: 0.0651 - accuracy: 0.9823 - val_loss: 0.0597 - val_accuracy: 0.9838 - 42s/epoch - 18ms/step
# Epoch 28/100
# 2344/2344 - 32s - loss: 0.0648 - accuracy: 0.9824 - val_loss: 0.0613 - val_accuracy: 0.9833 - 32s/epoch - 14ms/step
# Epoch 29/100
# 2344/2344 - 41s - loss: 0.0647 - accuracy: 0.9824 - val_loss: 0.0598 - val_accuracy: 0.9838 - 41s/epoch - 17ms/step
# Epoch 30/100
# 2344/2344 - 42s - loss: 0.0645 - accuracy: 0.9825 - val_loss: 0.0596 - val_accuracy: 0.9838 - 42s/epoch - 18ms/step
# Epoch 31/100
# 2344/2344 - 48s - loss: 0.0645 - accuracy: 0.9826 - val_loss: 0.0598 - val_accuracy: 0.9838 - 48s/epoch - 21ms/step
# Epoch 32/100
# 2344/2344 - 47s - loss: 0.0643 - accuracy: 0.9826 - val_loss: 0.0596 - val_accuracy: 0.9839 - 47s/epoch - 20ms/step
# Epoch 33/100
# 2344/2344 - 42s - loss: 0.0643 - accuracy: 0.9826 - val_loss: 0.0592 - val_accuracy: 0.9839 - 42s/epoch - 18ms/step
# Epoch 34/100
# 2344/2344 - 44s - loss: 0.0640 - accuracy: 0.9827 - val_loss: 0.0596 - val_accuracy: 0.9839 - 44s/epoch - 19ms/step
# Epoch 35/100
# 2344/2344 - 49s - loss: 0.0639 - accuracy: 0.9827 - val_loss: 0.0591 - val_accuracy: 0.9841 - 49s/epoch - 21ms/step
# Epoch 36/100
# 2344/2344 - 49s - loss: 0.0636 - accuracy: 0.9828 - val_loss: 0.0594 - val_accuracy: 0.9840 - 49s/epoch - 21ms/step
# Epoch 37/100
# 2344/2344 - 40s - loss: 0.0634 - accuracy: 0.9828 - val_loss: 0.0591 - val_accuracy: 0.9843 - 40s/epoch - 17ms/step
# Epoch 38/100
# 2344/2344 - 57s - loss: 0.0635 - accuracy: 0.9828 - val_loss: 0.0596 - val_accuracy: 0.9838 - 57s/epoch - 24ms/step
# Epoch 39/100
# 2344/2344 - 36s - loss: 0.0633 - accuracy: 0.9828 - val_loss: 0.0587 - val_accuracy: 0.9843 - 36s/epoch - 16ms/step
# Epoch 40/100
# 2344/2344 - 43s - loss: 0.0634 - accuracy: 0.9828 - val_loss: 0.0590 - val_accuracy: 0.9842 - 43s/epoch - 18ms/step
# Epoch 41/100
# 2344/2344 - 49s - loss: 0.0631 - accuracy: 0.9829 - val_loss: 0.0600 - val_accuracy: 0.9836 - 49s/epoch - 21ms/step
# Epoch 42/100
# 2344/2344 - 44s - loss: 0.0631 - accuracy: 0.9830 - val_loss: 0.0587 - val_accuracy: 0.9841 - 44s/epoch - 19ms/step
# Epoch 43/100
# 2344/2344 - 43s - loss: 0.0631 - accuracy: 0.9830 - val_loss: 0.0591 - val_accuracy: 0.9842 - 43s/epoch - 19ms/step
# Epoch 44/100
# 2344/2344 - 30s - loss: 0.0629 - accuracy: 0.9830 - val_loss: 0.0586 - val_accuracy: 0.9843 - 30s/epoch - 13ms/step
# Epoch 45/100
# 2344/2344 - 32s - loss: 0.0628 - accuracy: 0.9830 - val_loss: 0.0587 - val_accuracy: 0.9843 - 32s/epoch - 13ms/step
# Epoch 46/100
# 2344/2344 - 40s - loss: 0.0626 - accuracy: 0.9830 - val_loss: 0.0590 - val_accuracy: 0.9844 - 40s/epoch - 17ms/step
# Epoch 47/100
# 2344/2344 - 45s - loss: 0.0627 - accuracy: 0.9830 - val_loss: 0.0585 - val_accuracy: 0.9843 - 45s/epoch - 19ms/step
# Epoch 48/100
# 2344/2344 - 46s - loss: 0.0625 - accuracy: 0.9831 - val_loss: 0.0580 - val_accuracy: 0.9845 - 46s/epoch - 20ms/step
# Epoch 49/100
# 2344/2344 - 46s - loss: 0.0624 - accuracy: 0.9831 - val_loss: 0.0585 - val_accuracy: 0.9844 - 46s/epoch - 20ms/step
# Epoch 50/100
# 2344/2344 - 43s - loss: 0.0622 - accuracy: 0.9832 - val_loss: 0.0582 - val_accuracy: 0.9844 - 43s/epoch - 18ms/step
# Epoch 51/100
# 2344/2344 - 39s - loss: 0.0622 - accuracy: 0.9832 - val_loss: 0.0577 - val_accuracy: 0.9845 - 39s/epoch - 16ms/step
# Epoch 52/100
# 2344/2344 - 39s - loss: 0.0622 - accuracy: 0.9831 - val_loss: 0.0580 - val_accuracy: 0.9845 - 39s/epoch - 17ms/step
# Epoch 53/100
# 2344/2344 - 47s - loss: 0.0623 - accuracy: 0.9832 - val_loss: 0.0581 - val_accuracy: 0.9843 - 47s/epoch - 20ms/step
# Epoch 54/100
# 2344/2344 - 51s - loss: 0.0621 - accuracy: 0.9832 - val_loss: 0.0583 - val_accuracy: 0.9844 - 51s/epoch - 22ms/step
# Epoch 55/100
# 2344/2344 - 38s - loss: 0.0619 - accuracy: 0.9834 - val_loss: 0.0576 - val_accuracy: 0.9846 - 38s/epoch - 16ms/step
# Epoch 56/100
# 2344/2344 - 59s - loss: 0.0620 - accuracy: 0.9832 - val_loss: 0.0580 - val_accuracy: 0.9844 - 59s/epoch - 25ms/step
# Epoch 57/100
# 2344/2344 - 40s - loss: 0.0619 - accuracy: 0.9833 - val_loss: 0.0572 - val_accuracy: 0.9847 - 40s/epoch - 17ms/step
# Epoch 58/100
# 2344/2344 - 46s - loss: 0.0617 - accuracy: 0.9834 - val_loss: 0.0586 - val_accuracy: 0.9842 - 46s/epoch - 20ms/step
# Epoch 59/100
# 2344/2344 - 36s - loss: 0.0616 - accuracy: 0.9834 - val_loss: 0.0579 - val_accuracy: 0.9845 - 36s/epoch - 15ms/step
# Epoch 60/100
# 2344/2344 - 45s - loss: 0.0617 - accuracy: 0.9833 - val_loss: 0.0576 - val_accuracy: 0.9845 - 45s/epoch - 19ms/step
# Epoch 61/100
# 2344/2344 - 49s - loss: 0.0617 - accuracy: 0.9834 - val_loss: 0.0575 - val_accuracy: 0.9845 - 49s/epoch - 21ms/step
# Epoch 62/100
# 2344/2344 - 45s - loss: 0.0615 - accuracy: 0.9835 - val_loss: 0.0575 - val_accuracy: 0.9847 - 45s/epoch - 19ms/step
# Epoch 63/100
# 2344/2344 - 40s - loss: 0.0615 - accuracy: 0.9834 - val_loss: 0.0576 - val_accuracy: 0.9847 - 40s/epoch - 17ms/step
# Epoch 64/100
# 2344/2344 - 53s - loss: 0.0612 - accuracy: 0.9834 - val_loss: 0.0572 - val_accuracy: 0.9846 - 53s/epoch - 23ms/step
# Epoch 65/100
# 2344/2344 - 59s - loss: 0.0613 - accuracy: 0.9835 - val_loss: 0.0571 - val_accuracy: 0.9847 - 59s/epoch - 25ms/step
# Epoch 66/100
# 2344/2344 - 40s - loss: 0.0613 - accuracy: 0.9835 - val_loss: 0.0575 - val_accuracy: 0.9847 - 40s/epoch - 17ms/step
# Epoch 67/100
# 2344/2344 - 35s - loss: 0.0612 - accuracy: 0.9835 - val_loss: 0.0574 - val_accuracy: 0.9846 - 35s/epoch - 15ms/step
# Epoch 68/100
# 2344/2344 - 48s - loss: 0.0612 - accuracy: 0.9835 - val_loss: 0.0571 - val_accuracy: 0.9847 - 48s/epoch - 20ms/step
# Epoch 69/100
# 2344/2344 - 49s - loss: 0.0610 - accuracy: 0.9836 - val_loss: 0.0583 - val_accuracy: 0.9844 - 49s/epoch - 21ms/step
# Epoch 70/100
# 2344/2344 - 38s - loss: 0.0609 - accuracy: 0.9835 - val_loss: 0.0572 - val_accuracy: 0.9847 - 38s/epoch - 16ms/step
# Epoch 71/100
# 2344/2344 - 30s - loss: 0.0611 - accuracy: 0.9835 - val_loss: 0.0574 - val_accuracy: 0.9847 - 30s/epoch - 13ms/step
# Epoch 72/100
# 2344/2344 - 28s - loss: 0.0610 - accuracy: 0.9836 - val_loss: 0.0569 - val_accuracy: 0.9847 - 28s/epoch - 12ms/step
# Epoch 73/100
# 2344/2344 - 40s - loss: 0.0610 - accuracy: 0.9836 - val_loss: 0.0577 - val_accuracy: 0.9846 - 40s/epoch - 17ms/step
# Epoch 74/100
# 2344/2344 - 40s - loss: 0.0607 - accuracy: 0.9836 - val_loss: 0.0591 - val_accuracy: 0.9841 - 40s/epoch - 17ms/step
# Epoch 75/100
# 2344/2344 - 38s - loss: 0.0608 - accuracy: 0.9836 - val_loss: 0.0580 - val_accuracy: 0.9841 - 38s/epoch - 16ms/step
# Epoch 76/100
# 2344/2344 - 35s - loss: 0.0608 - accuracy: 0.9836 - val_loss: 0.0569 - val_accuracy: 0.9848 - 35s/epoch - 15ms/step
# Epoch 77/100
# 2344/2344 - 58s - loss: 0.0606 - accuracy: 0.9837 - val_loss: 0.0566 - val_accuracy: 0.9849 - 58s/epoch - 25ms/step
# Epoch 78/100
# 2344/2344 - 44s - loss: 0.0608 - accuracy: 0.9836 - val_loss: 0.0568 - val_accuracy: 0.9849 - 44s/epoch - 19ms/step
# Epoch 79/100
# 2344/2344 - 37s - loss: 0.0607 - accuracy: 0.9836 - val_loss: 0.0567 - val_accuracy: 0.9849 - 37s/epoch - 16ms/step
# Epoch 80/100
# 2344/2344 - 47s - loss: 0.0605 - accuracy: 0.9837 - val_loss: 0.0568 - val_accuracy: 0.9847 - 47s/epoch - 20ms/step
# Epoch 81/100
# 2344/2344 - 76s - loss: 0.0606 - accuracy: 0.9837 - val_loss: 0.0572 - val_accuracy: 0.9846 - 76s/epoch - 32ms/step
# Epoch 82/100
# 2344/2344 - 61s - loss: 0.0605 - accuracy: 0.9837 - val_loss: 0.0571 - val_accuracy: 0.9846 - 61s/epoch - 26ms/step
# Epoch 83/100
# 2344/2344 - 41s - loss: 0.0607 - accuracy: 0.9836 - val_loss: 0.0571 - val_accuracy: 0.9848 - 41s/epoch - 17ms/step
# Epoch 84/100
# 2344/2344 - 34s - loss: 0.0604 - accuracy: 0.9838 - val_loss: 0.0567 - val_accuracy: 0.9849 - 34s/epoch - 14ms/step
# Epoch 85/100
# 2344/2344 - 39s - loss: 0.0602 - accuracy: 0.9838 - val_loss: 0.0570 - val_accuracy: 0.9848 - 39s/epoch - 17ms/step
# Epoch 86/100
# 2344/2344 - 52s - loss: 0.0605 - accuracy: 0.9837 - val_loss: 0.0568 - val_accuracy: 0.9848 - 52s/epoch - 22ms/step
# Epoch 87/100
# 2344/2344 - 56s - loss: 0.0602 - accuracy: 0.9838 - val_loss: 0.0568 - val_accuracy: 0.9850 - 56s/epoch - 24ms/step
# Epoch 88/100
# 2344/2344 - 45s - loss: 0.0604 - accuracy: 0.9838 - val_loss: 0.0572 - val_accuracy: 0.9848 - 45s/epoch - 19ms/step
# Epoch 89/100
# 2344/2344 - 48s - loss: 0.0602 - accuracy: 0.9837 - val_loss: 0.0571 - val_accuracy: 0.9849 - 48s/epoch - 20ms/step
# Epoch 90/100
# 2344/2344 - 40s - loss: 0.0605 - accuracy: 0.9837 - val_loss: 0.0562 - val_accuracy: 0.9851 - 40s/epoch - 17ms/step
# Epoch 91/100
# 2344/2344 - 44s - loss: 0.0602 - accuracy: 0.9838 - val_loss: 0.0561 - val_accuracy: 0.9848 - 44s/epoch - 19ms/step
# Epoch 92/100
# 2344/2344 - 52s - loss: 0.0601 - accuracy: 0.9838 - val_loss: 0.0563 - val_accuracy: 0.9850 - 52s/epoch - 22ms/step
# Epoch 93/100
# 2344/2344 - 35s - loss: 0.0601 - accuracy: 0.9838 - val_loss: 0.0568 - val_accuracy: 0.9848 - 35s/epoch - 15ms/step
# Epoch 94/100
# 2344/2344 - 32s - loss: 0.0600 - accuracy: 0.9839 - val_loss: 0.0567 - val_accuracy: 0.9848 - 32s/epoch - 14ms/step
# Epoch 95/100
# 2344/2344 - 39s - loss: 0.0600 - accuracy: 0.9839 - val_loss: 0.0567 - val_accuracy: 0.9848 - 39s/epoch - 17ms/step
# Epoch 96/100
# 2344/2344 - 36s - loss: 0.0601 - accuracy: 0.9838 - val_loss: 0.0564 - val_accuracy: 0.9850 - 36s/epoch - 15ms/step
# Epoch 97/100
# 2344/2344 - 43s - loss: 0.0600 - accuracy: 0.9838 - val_loss: 0.0571 - val_accuracy: 0.9848 - 43s/epoch - 18ms/step
# Epoch 98/100
# 2344/2344 - 41s - loss: 0.0599 - accuracy: 0.9839 - val_loss: 0.0561 - val_accuracy: 0.9851 - 41s/epoch - 17ms/step
# Epoch 99/100
# 2344/2344 - 41s - loss: 0.0600 - accuracy: 0.9839 - val_loss: 0.0569 - val_accuracy: 0.9847 - 41s/epoch - 18ms/step
# Epoch 100/100
# 2344/2344 - 39s - loss: 0.0600 - accuracy: 0.9839 - val_loss: 0.0568 - val_accuracy: 0.9848 - 39s/epoch - 17ms/step

# %%
#Training  model 2  with different structure
initializer = tf.keras.initializers.GlorotUniform(seed=33)
constraints = None

model_2 = tf.keras.Sequential([
      tf.keras.layers.Dense(64, input_dim=X.shape[1], kernel_initializer=initializer, activation='relu',name='dense_2a'),
      tf.keras.layers.Dense(128, input_dim=64, kernel_initializer=initializer, activation='relu',name='dense_2b'),
      tf.keras.layers.Dropout(0.3),
      tf.keras.layers.Dense(256, input_dim=128, kernel_initializer=initializer, activation='relu',name='dense_2c'),
      tf.keras.layers.Dropout(0.2),
      tf.keras.layers.Dense(128, input_dim=256, kernel_initializer=initializer, activation='relu',name='dense_2d'),
      tf.keras.layers.Dropout(0.1),
      tf.keras.layers.Dense(Y.shape[1],activation='softmax')
      ])

# %%
#from tensorflow.keras.callbacks import EarlyStopping

model_2.compile(loss='categorical_crossentropy',metrics=['accuracy'], optimizer='adam')

log_dir_2 = colab_model_write_path + "model_2" + datetime.now().strftime("%Y%m%d%H%M%S")

monitor_2 = [
             tf.keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=1e-5, patience=8, verbose=1, mode='auto',restore_best_weights=True),
             tf.keras.callbacks.TensorBoard(log_dir=log_dir_2, histogram_freq=1)
            ]
history_2  = model_2.fit(x_train,y_train,validation_data=(x_test,y_test), callbacks=[monitor_2],verbose=2, batch_size=512, epochs=100)
model_2.save(colab_model_write_path + 'model2.h5')
# Out:
# Epoch 1/100
# 4688/4688 - 33s - loss: 0.1426 - accuracy: 0.9600 - val_loss: 0.0871 - val_accuracy: 0.9767 - 33s/epoch - 7ms/step
# Epoch 2/100
# 4688/4688 - 32s - loss: 0.0890 - accuracy: 0.9764 - val_loss: 0.0756 - val_accuracy: 0.9795 - 32s/epoch - 7ms/step
# Epoch 3/100
# 4688/4688 - 32s - loss: 0.0818 - accuracy: 0.9782 - val_loss: 0.0726 - val_accuracy: 0.9801 - 32s/epoch - 7ms/step
# Epoch 4/100
# 4688/4688 - 32s - loss: 0.0781 - accuracy: 0.9790 - val_loss: 0.0707 - val_accuracy: 0.9807 - 32s/epoch - 7ms/step
# Epoch 5/100
# 4688/4688 - 31s - loss: 0.0758 - accuracy: 0.9795 - val_loss: 0.0693 - val_accuracy: 0.9811 - 31s/epoch - 7ms/step
# Epoch 6/100
# 4688/4688 - 32s - loss: 0.0742 - accuracy: 0.9800 - val_loss: 0.0667 - val_accuracy: 0.9816 - 32s/epoch - 7ms/step
# Epoch 7/100
# 4688/4688 - 33s - loss: 0.0727 - accuracy: 0.9803 - val_loss: 0.0676 - val_accuracy: 0.9816 - 33s/epoch - 7ms/step
# Epoch 8/100
# 4688/4688 - 33s - loss: 0.0716 - accuracy: 0.9806 - val_loss: 0.0649 - val_accuracy: 0.9824 - 33s/epoch - 7ms/step
# Epoch 9/100
# 4688/4688 - 33s - loss: 0.0707 - accuracy: 0.9808 - val_loss: 0.0660 - val_accuracy: 0.9821 - 33s/epoch - 7ms/step
# Epoch 10/100
# 4688/4688 - 32s - loss: 0.0699 - accuracy: 0.9810 - val_loss: 0.0645 - val_accuracy: 0.9826 - 32s/epoch - 7ms/step
# Epoch 11/100
# 4688/4688 - 31s - loss: 0.0692 - accuracy: 0.9813 - val_loss: 0.0646 - val_accuracy: 0.9821 - 31s/epoch - 7ms/step
# Epoch 12/100
# 4688/4688 - 32s - loss: 0.0687 - accuracy: 0.9815 - val_loss: 0.0653 - val_accuracy: 0.9820 - 32s/epoch - 7ms/step
# Epoch 13/100
- val_accuracy: 0.9845 - 32s/epoch - 7ms/step
# Epoch 70/100
# 4688/4688 - 32s - loss: 0.0618 - accuracy: 0.9836 - val_loss: 0.0576 - val_accuracy: 0.9846 - 32s/epoch - 7ms/step
# Epoch 71/100
# 4688/4688 - 33s - loss: 0.0619 - accuracy: 0.9835 - val_loss: 0.0574 - val_accuracy: 0.9848 - 33s/epoch - 7ms/step
# Epoch 72/100
# 4688/4688 - 32s - loss: 0.0620 - accuracy: 0.9835 - val_loss: 0.0580 - val_accuracy: 0.9845 - 32s/epoch - 7ms/step
# Epoch 73/100
# 4688/4688 - 32s - loss: 0.0618 - accuracy: 0.9836 - val_loss: 0.0580 - val_accuracy: 0.9845 - 32s/epoch - 7ms/step
# Epoch 74/100
# Restoring model weights from the end of the best epoch: 66.
# 4688/4688 - 32s - loss: 0.0617 - accuracy: 0.9836 - val_loss: 0.0570 - val_accuracy: 0.9848 - 32s/epoch - 7ms/step
# Epoch 74: early stopping

# %%
#3 rd model for stack
initializer = tf.keras.initializers.GlorotUniform(seed=33)
constraints = None

model_3 = tf.keras.Sequential([
      tf.keras.layers.Dense(512, input_dim=X.shape[1], kernel_initializer=initializer, activation='relu',name='dense_3a'),
      tf.keras.layers.Dropout(0.1),
      tf.keras.layers.Dense(256, input_dim=X.shape[1], kernel_initializer=initializer, activation='relu',name='dense_3b'),
      tf.keras.layers.Dropout(0.3),
      tf.keras.layers.Dense(128, input_dim=X.shape[1], kernel_initializer=initializer, activation='relu',name='dense_3c'),
      tf.keras.layers.Dropout(0.2),
      tf.keras.layers.Dense(128, input_dim=X.shape[1], kernel_initializer=initializer, activation='relu',name='dense_3d'),
      tf.keras.layers.Dense(Y.shape[1],activation='softmax')
      ])

# %%
model_3.compile(loss='categorical_crossentropy',metrics=['accuracy'], optimizer='adam')

log_dir = colab_model_write_path + "model_3" + datetime.now().strftime("%Y%m%d%H%M%S")

monitor_3 = [
             tf.keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=1e-5, patience=8, verbose=2, mode='auto',restore_best_weights=True),
             tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)
            ]
history_3  = model_3.fit(x_train,y_train,validation_data=(x_test,y_test), callbacks=[monitor_3],verbose=2, batch_size=512, epochs=100)
model_3.save(colab_model_write_path + 'model3.h5')
# Out:
# Epoch 1/100
# 4688/4688 - 59s - loss: 0.1244 - accuracy: 0.9655 - val_loss: 0.0877 - val_accuracy: 0.9777 - 59s/epoch - 12ms/step
# Epoch 2/100
# 4688/4688 - 59s - loss: 0.0842 - accuracy: 0.9777 - val_loss: 0.0758 - val_accuracy: 0.9796 - 59s/epoch - 13ms/step
# Epoch 3/100
# 4688/4688 - 55s - loss: 0.0783 - accuracy: 0.9790 - val_loss: 0.0696 - val_accuracy: 0.9810 - 55s/epoch - 12ms/step
# Epoch 4/100
# 4688/4688 - 61s - loss: 0.0751 - accuracy: 0.9797 - val_loss: 0.0678 - val_accuracy: 0.9814 - 61s/epoch - 13ms/step
# Epoch 5/100
# 4688/4688 - 57s - loss: 0.0727 - accuracy: 0.9803 - val_loss: 0.0666 - val_accuracy: 0.9815 - 57s/epoch - 12ms/step
# Epoch 6/100
# 4688/4688 - 55s - loss: 0.0712 - accuracy: 0.9806 - val_loss: 0.0667 - val_accuracy: 0.9817 - 55s/epoch - 12ms/step
# Epoch 7/100
# 4688/4688 - 55s - loss: 0.0700 - accuracy: 0.9809 - val_loss: 0.0658 - val_accuracy: 0.9822 - 55s/epoch - 12ms/step
# Epoch 43/100
# 4688/4688 - 57s - loss: 0.0611 - accuracy: 0.9837 - val_loss: 0.0591 - val_accuracy: 0.9847 - 57s/epoch - 12ms/step
# Epoch 44/100
# Restoring model weights from the end of the best epoch: 36.
# 4688/4688 - 58s - loss: 0.0611 - accuracy: 0.9838 - val_loss: 0.0592 - val_accuracy: 0.9846 - 58s/epoch - 12ms/step
# Epoch 44: early stopping

# %%
#4 rd model for stack
initializer = tf.keras.initializers.GlorotUniform(seed=33)
constraints = None

model_4 = tf.keras.Sequential([
      tf.keras.layers.Dense(128, input_dim=x_train.shape[1], kernel_initializer=initializer, activation='relu',name='dense_4a'),
      tf.keras.layers.Dropout(0.3),
      tf.keras.layers.Dense(64, input_dim=x_train.shape[1], kernel_initializer=initializer, activation='relu',name='dense_4b'),
      tf.keras.layers.Dropout(0.1),
      tf.keras.layers.Dense(64, input_dim=x_train.shape[1], kernel_initializer=initializer, activation='relu',name='dense_4c'),
      tf.keras.layers.Dropout(0.1),
      tf.keras.layers.Dense(128, input_dim=x_train.shape[1], kernel_initializer=initializer, activation='relu',name='dense_4d'),
      tf.keras.layers.Dense(y_train.shape[1],activation='softmax')
      ])

# %%
model_4.compile(loss='categorical_crossentropy',metrics=['accuracy'], optimizer='adam')

log_dir_4 = colab_model_write_path + "model_4" + datetime.now().strftime("%Y%m%d%H%M%S")

monitor_4 = [
            tf.keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=1e-5, patience=100, verbose=1, mode='auto',restore_best_weights=True),
            tf.keras.callbacks.TensorBoard(log_dir=log_dir_4, histogram_freq=1)
        ]
history_4  = model_4.fit(x_train,y_train,validation_data=(x_test,y_test), callbacks=[monitor_4],verbose=2, batch_size=512, epochs=100)
model_4.save(colab_model_write_path + 'model4.h5')
# Out:
# Epoch 1/100
# 4688/4688 - 23s - loss: 0.1675 - accuracy: 0.9515 - val_loss: 0.0909 - val_accuracy: 0.9759 - 23s/epoch - 5ms/step
# Epoch 2/100
# 4688/4688 - 22s - loss: 0.0999 - accuracy: 0.9732 - val_loss: 0.0809 - val_accuracy: 0.9783 - 22s/epoch - 5ms/step
# Epoch 3/100
# 4688/4688 - 22s - loss: 0.0911 - accuracy: 0.9756 - val_loss: 0.0752 - val_accuracy: 0.9794 - 22s/epoch - 5ms/step
# Epoch 4/100
# 4688/4688 - 22s - loss: 0.0869 - accuracy: 0.9766 - val_loss: 0.0740 - val_accuracy: 0.9796 - 22s/epoch - 5ms/step
# Epoch 5/100
# 4688/4688 - 22s - loss: 0.0844 - accuracy: 0.9772 - val_loss: 0.0721 - val_accuracy: 0.9803 - 22s/epoch - 5ms/step
# Epoch 6/100
# 4688/4688 - 23s - loss: 0.0826 - accuracy: 0.9776 - val_loss: 0.0708 - val_accuracy: 0.9804 - 23s/epoch - 5ms/step
# Epoch 7/100
# 4688/4688 - 22s - loss: 0.0812 - accuracy: 0.9779 - val_loss: 0.0702 - val_accuracy: 0.9807 - 22s/epoch - 5ms/step
# Epoch 8/100
# 4688/4688 - 24s - loss: 0.0800 - accuracy: 0.9782 - val_loss: 0.0683 - val_accuracy: 0.9814 - 24s/epoch - 5ms/step
# Epoch 9/100
# 4688/4688 - 23s - loss: 0.0791 - accuracy: 0.9784 - val_loss: 0.0683 - val_accuracy: 0.9813 - 23s/epoch - 5ms/step
# Epoch 10/100
# 4688/4688 - 23s - loss: 0.0782 - accuracy: 0.9786 - val_loss: 0.0676 - val_accuracy: 0.9813 - 23s/epoch - 5ms/step
# Epoch 11/100
# 4688/4688 - 23s - loss: 0.0775 - accuracy: 0.9788 - val_loss: 0.0670 - val_accuracy: 0.9817 - 23s/epoch - 5ms/step
# Epoch 12/100
# 4688/4688 - 23s - loss: 0.0769 - accuracy: 0.9790 - val_loss: 0.0672 - val_accuracy: 0.9819 - 23s/epoch - 5ms/step
# Epoch 13/100
# 4688/4688 - 23s - loss: 0.0765 - accuracy: 0.9790 - val_loss: 0.0666 - val_accuracy: 0.9817 - 23s/epoch - 5ms/step
# Epoch 14/100
# 4688/4688 - 24s - loss: 0.0760 - accuracy: 0.9793 - val_loss: 0.0665 - val_accuracy: 0.9817 - 24s/epoch - 5ms/step
# Epoch 15/100
# 4688/4688 - 23s - loss: 0.0758 - accuracy: 0.9792 - val_loss: 0.0657 - val_accuracy: 0.9819 - 23s/epoch - 5ms/step
# Epoch 16/100
# 4688/4688 - 24s - loss: 0.0755 - accuracy: 0.9794 - val_loss: 0.0655 - val_accuracy: 0.9820 - 24s/epoch - 5ms/step
# Epoch 17/100
# 4688/4688 - 22s - loss: 0.0749 - accuracy: 0.9795 - val_loss: 0.0658 - val_accuracy: 0.9820 - 22s/epoch - 5ms/step
# Epoch 18/100
# 4688/4688 - 24s - loss: 0.0745 - accuracy: 0.9796 - val_loss: 0.0655 - val_accuracy: 0.9821 - 24s/epoch - 5ms/step
# Epoch 19/100
# 4688/4688 - 22s - loss: 0.0742 - accuracy: 0.9797 - val_loss: 0.0648 - val_accuracy: 0.9821 - 22s/epoch - 5ms/step
# Epoch 20/100
# 4688/4688 - 24s - loss: 0.0740 - accuracy: 0.9797 - val_loss: 0.0649 - val_accuracy: 0.9822 - 24s/epoch - 5ms/step
# Epoch 21/100
# 4688/4688 - 23s - loss: 0.0736 - accuracy: 0.9799 - val_loss: 0.0648 - val_accuracy: 0.9821 - 23s/epoch - 5ms/step
# Epoch 22/100
# 4688/4688 - 23s - loss: 0.0734 - accuracy: 0.9799 - val_loss: 0.0645 - val_accuracy: 0.9825 - 23s/epoch - 5ms/step
# Epoch 23/100
# 4688/4688 - 23s - loss: 0.0731 - accuracy: 0.9800 - val_loss: 0.0634 - val_accuracy: 0.9825 - 23s/epoch - 5ms/step
# Epoch 24/100
# 4688/4688 - 22s - loss: 0.0731 - accuracy: 0.9801 - val_loss: 0.0637 - val_accuracy: 0.9825 - 22s/epoch - 5ms/step
# Epoch 25/100
# 4688/4688 - 23s - loss: 0.0727 - accuracy: 0.9801 - val_loss: 0.0635 - val_accuracy: 0.9828 - 23s/epoch - 5ms/step
# Epoch 26/100
# 4688/4688 - 23s - loss: 0.0724 - accuracy: 0.9802 - val_loss: 0.0629 - val_accuracy: 0.9830 - 23s/epoch - 5ms/step
# Epoch 27/100
# 4688/4688 - 22s - loss: 0.0723 - accuracy: 0.9803 - val_loss: 0.0635 - val_accuracy: 0.9828 - 22s/epoch - 5ms/step
# Epoch 28/100
# 4688/4688 - 23s - loss: 0.0723 - accuracy: 0.9803 - val_loss: 0.0629 - val_accuracy: 0.9829 - 23s/epoch - 5ms/step
# Epoch 29/100
# 4688/4688 - 23s - loss: 0.0719 - accuracy: 0.9804 - val_loss: 0.0636 - val_accuracy: 0.9828 - 23s/epoch - 5ms/step
# Epoch 30/100
# 4688/4688 - 23s - loss: 0.0718 - accuracy: 0.9804 - val_loss: 0.0627 - val_accuracy: 0.9826 - 23s/epoch - 5ms/step
# Epoch 31/100
# 4688/4688 - 23s - loss: 0.0718 - accuracy: 0.9805 - val_loss: 0.0626 - val_accuracy: 0.9831 - 23s/epoch - 5ms/step
# Epoch 32/100
# 4688/4688 - 23s - loss: 0.0718 - accuracy: 0.9805 - val_loss: 0.0627 - val_accuracy: 0.9829 - 23s/epoch - 5ms/step
# Epoch 33/100
# 4688/4688 - 23s - loss: 0.0713 - accuracy: 0.9806 - val_loss: 0.0623 - val_accuracy: 0.9831 - 23s/epoch - 5ms/step
# Epoch 34/100
# 4688/4688 - 23s - loss: 0.0714 - accuracy: 0.9806 - val_loss: 0.0626 - val_accuracy: 0.9831 - 23s/epoch - 5ms/step
# Epoch 35/100
# 4688/4688 - 22s - loss: 0.0713 - accuracy: 0.9806 - val_loss: 0.0623 - val_accuracy: 0.9830 - 22s/epoch - 5ms/step
# Epoch 36/100
# 4688/4688 - 24s - loss: 0.0712 - accuracy: 0.9805 - val_loss: 0.0622 - val_accuracy: 0.9831 - 24s/epoch - 5ms/step
# Epoch 37/100
# 4688/4688 - 23s - loss: 0.0708 - accuracy: 0.9807 - val_loss: 0.0618 - val_accuracy: 0.9832 - 23s/epoch - 5ms/step
# Epoch 38/100
# 4688/4688 - 22s - loss: 0.0708 - accuracy: 0.9807 - val_loss: 0.0622 - val_accuracy: 0.9830 - 22s/epoch - 5ms/step
# Epoch 39/100
# 4688/4688 - 23s - loss: 0.0706 - accuracy: 0.9807 - val_loss: 0.0620 - val_accuracy: 0.9833 - 23s/epoch - 5ms/step
# Epoch 40/100
# 4688/4688 - 22s - loss: 0.0708 - accuracy: 0.9807 - val_loss: 0.0619 - val_accuracy: 0.9834 - 22s/epoch - 5ms/step
# Epoch 41/100
# 4688/4688 - 23s - loss: 0.0705 - accuracy: 0.9808 - val_loss: 0.0614 - val_accuracy: 0.9832 - 23s/epoch - 5ms/step
# Epoch 42/100
# 4688/4688 - 23s - loss: 0.0703 - accuracy: 0.9809 - val_loss: 0.0621 - val_accuracy: 0.9832 - 23s/epoch - 5ms/step
# Epoch 43/100
# 4688/4688 - 23s - loss: 0.0703 - accuracy: 0.9808 - val_loss: 0.0618 - val_accuracy: 0.9831 - 23s/epoch - 5ms/step
# Epoch 44/100
# 4688/4688 - 24s - loss: 0.0702 - accuracy: 0.9809 - val_loss: 0.0615 - val_accuracy: 0.9832 - 24s/epoch - 5ms/step
# Epoch 45/100
# 4688/4688 - 23s - loss: 0.0703 - accuracy: 0.9809 - val_loss: 0.0616 - val_accuracy: 0.9833 - 23s/epoch - 5ms/step
# Epoch 46/100
# 4688/4688 - 22s - loss: 0.0701 - accuracy: 0.9810 - val_loss: 0.0624 - val_accuracy: 0.9830 - 22s/epoch - 5ms/step
# Epoch 47/100
# 4688/4688 - 23s - loss: 0.0699 - accuracy: 0.9810 - val_loss: 0.0630 - val_accuracy: 0.9827 - 23s/epoch - 5ms/step
# Epoch 48/100
# 4688/4688 - 23s - loss: 0.0701 - accuracy: 0.9809 - val_loss: 0.0614 - val_accuracy: 0.9835 - 23s/epoch - 5ms/step
# Epoch 49/100
# 4688/4688 - 24s - loss: 0.0698 - accuracy: 0.9811 - val_loss: 0.0610 - val_accuracy: 0.9837 - 24s/epoch - 5ms/step
# Epoch 50/100
# 4688/4688 - 23s - loss: 0.0696 - accuracy: 0.9810 - val_loss: 0.0618 - val_accuracy: 0.9834 - 23s/epoch - 5ms/step
# Epoch 51/100
# 4688/4688 - 23s - loss: 0.0695 - accuracy: 0.9811 - val_loss: 0.0615 - val_accuracy: 0.9836 - 23s/epoch - 5ms/step
# Epoch 52/100
# 4688/4688 - 23s - loss: 0.0695 - accuracy: 0.9811 - val_loss: 0.0615 - val_accuracy: 0.9834 - 23s/epoch - 5ms/step
# Epoch 53/100
# 4688/4688 - 23s - loss: 0.0696 - accuracy: 0.9810 - val_loss: 0.0610 - val_accuracy: 0.9837 - 23s/epoch - 5ms/step
# Epoch 54/100
# 4688/4688 - 23s - loss: 0.0695 - accuracy: 0.9811 - val_loss: 0.0608 - val_accuracy: 0.9837 - 23s/epoch - 5ms/step
# Epoch 55/100
# 4688/4688 - 23s - loss: 0.0694 - accuracy: 0.9812 - val_loss: 0.0616 - val_accuracy: 0.9834 - 23s/epoch - 5ms/step
# Epoch 56/100
# 4688/4688 - 23s - loss: 0.0693 - accuracy: 0.9812 - val_loss: 0.0607 - val_accuracy: 0.9837 - 23s/epoch - 5ms/step
# Epoch 57/100
# 4688/4688 - 22s - loss: 0.0694 - accuracy: 0.9811 - val_loss: 0.0608 - val_accuracy: 0.9837 - 22s/epoch - 5ms/step
# Epoch 58/100
# 4688/4688 - 22s - loss: 0.0691 - accuracy: 0.9812 - val_loss: 0.0609 - val_accuracy: 0.9836 - 22s/epoch - 5ms/step
# Epoch 59/100
# 4688/4688 - 23s - loss: 0.0692 - accuracy: 0.9812 - val_loss: 0.0616 - val_accuracy: 0.9832 - 23s/epoch - 5ms/step
# Epoch 60/100
# 4688/4688 - 24s - loss: 0.0691 - accuracy: 0.9812 - val_loss: 0.0604 - val_accuracy: 0.9838 - 24s/epoch - 5ms/step
# Epoch 61/100
# 4688/4688 - 23s - loss: 0.0691 - accuracy: 0.9813 - val_loss: 0.0612 - val_accuracy: 0.9834 - 23s/epoch - 5ms/step
# Epoch 62/100
# 4688/4688 - 22s - loss: 0.0689 - accuracy: 0.9813 - val_loss: 0.0609 - val_accuracy: 0.9835 - 22s/epoch - 5ms/step
# Epoch 63/100
# 4688/4688 - 23s - loss: 0.0690 - accuracy: 0.9813 - val_loss: 0.0608 - val_accuracy: 0.9835 - 23s/epoch - 5ms/step
# Epoch 64/100
# 4688/4688 - 23s - loss: 0.0693 - accuracy: 0.9812 - val_loss: 0.0607 - val_accuracy: 0.9834 - 23s/epoch - 5ms/step
# Epoch 65/100
# 4688/4688 - 23s - loss: 0.0688 - accuracy: 0.9813 - val_loss: 0.0605 - val_accuracy: 0.9837 - 23s/epoch - 5ms/step
# Epoch 66/100
# 4688/4688 - 23s - loss: 0.0689 - accuracy: 0.9814 - val_loss: 0.0610 - val_accuracy: 0.9837 - 23s/epoch - 5ms/step
# Epoch 67/100
# 4688/4688 - 23s - loss: 0.0687 - accuracy: 0.9814 - val_loss: 0.0616 - val_accuracy: 0.9832 - 23s/epoch - 5ms/step
# Epoch 68/100
# 4688/4688 - 23s - loss: 0.0690 - accuracy: 0.9812 - val_loss: 0.0605 - val_accuracy: 0.9838 - 23s/epoch - 5ms/step
# Epoch 69/100
# 4688/4688 - 24s - loss: 0.0689 - accuracy: 0.9813 - val_loss: 0.0605 - val_accuracy: 0.9838 - 24s/epoch - 5ms/step
# Epoch 70/100
# 4688/4688 - 25s - loss: 0.0686 - accuracy: 0.9814 - val_loss: 0.0603 - val_accuracy: 0.9838 - 25s/epoch - 5ms/step
# Epoch 71/100
# 4688/4688 - 23s - loss: 0.0686 - accuracy: 0.9814 - val_loss: 0.0603 - val_accuracy: 0.9837 - 23s/epoch - 5ms/step
# Epoch 72/100
# 4688/4688 - 24s - loss: 0.0686 - accuracy: 0.9814 - val_loss: 0.0603 - val_accuracy: 0.9839 - 24s/epoch - 5ms/step
# Epoch 73/100
# 4688/4688 - 22s - loss: 0.0685 - accuracy: 0.9814 - val_loss: 0.0601 - val_accuracy: 0.9841 - 22s/epoch - 5ms/step
# Epoch 74/100
# 4688/4688 - 23s - loss: 0.0685 - accuracy: 0.9814 - val_loss: 0.0600 - val_accuracy: 0.9839 - 23s/epoch - 5ms/step
# Epoch 75/100
# 4688/4688 - 24s - loss: 0.0683 - accuracy: 0.9815 - val_loss: 0.0601 - val_accuracy: 0.9838 - 24s/epoch - 5ms/step
# Epoch 76/100
# 4688/4688 - 24s - loss: 0.0686 - accuracy: 0.9814 - val_loss: 0.0601 - val_accuracy: 0.9838 - 24s/epoch - 5ms/step
# Epoch 77/100
# 4688/4688 - 22s - loss: 0.0684 - accuracy: 0.9814 - val_loss: 0.0604 - val_accuracy: 0.9838 - 22s/epoch - 5ms/step
# Epoch 78/100
# 4688/4688 - 22s - loss: 0.0684 - accuracy: 0.9816 - val_loss: 0.0602 - val_accuracy: 0.9837 - 22s/epoch - 5ms/step
# Epoch 79/100
# 4688/4688 - 23s - loss: 0.0682 - accuracy: 0.9815 - val_loss: 0.0601 - val_accuracy: 0.9838 - 23s/epoch - 5ms/step
# Epoch 80/100
# 4688/4688 - 24s - loss: 0.0684 - accuracy: 0.9815 - val_loss: 0.0606 - val_accuracy: 0.9837 - 24s/epoch - 5ms/step
# Epoch 81/100
# 4688/4688 - 23s - loss: 0.0681 - accuracy: 0.9815 - val_loss: 0.0607 - val_accuracy: 0.9834 - 23s/epoch - 5ms/step
# Epoch 82/100
# 4688/4688 - 24s - loss: 0.0684 - accuracy: 0.9815 - val_loss: 0.0601 - val_accuracy: 0.9839 - 24s/epoch - 5ms/step
# Epoch 83/100
# 4688/4688 - 23s - loss: 0.0684 - accuracy: 0.9815 - val_loss: 0.0603 - val_accuracy: 0.9839 - 23s/epoch - 5ms/step
# Epoch 84/100
# 4688/4688 - 23s - loss: 0.0681 - accuracy: 0.9816 - val_loss: 0.0599 - val_accuracy: 0.9839 - 23s/epoch - 5ms/step
# Epoch 85/100
# 4688/4688 - 24s - loss: 0.0683 - accuracy: 0.9815 - val_loss: 0.0604 - val_accuracy: 0.9839 - 24s/epoch - 5ms/step
# Epoch 86/100
# 4688/4688 - 22s - loss: 0.0684 - accuracy: 0.9816 - val_loss: 0.0600 - val_accuracy: 0.9840 - 22s/epoch - 5ms/step
# Epoch 87/100
# 4688/4688 - 23s - loss: 0.0682 - accuracy: 0.9816 - val_loss: 0.0599 - val_accuracy: 0.9839 - 23s/epoch - 5ms/step
# Epoch 88/100
# 4688/4688 - 23s - loss: 0.0682 - accuracy: 0.9815 - val_loss: 0.0602 - val_accuracy: 0.9838 - 23s/epoch - 5ms/step
# Epoch 89/100
# 4688/4688 - 23s - loss: 0.0681 - accuracy: 0.9816 - val_loss: 0.0596 - val_accuracy: 0.9841 - 23s/epoch - 5ms/step
# Epoch 90/100
# 4688/4688 - 23s - loss: 0.0682 - accuracy: 0.9816 - val_loss: 0.0602 - val_accuracy: 0.9840 - 23s/epoch - 5ms/step
# Epoch 91/100
# 4688/4688 - 22s - loss: 0.0679 - accuracy: 0.9817 - val_loss: 0.0600 - val_accuracy: 0.9840 - 22s/epoch - 5ms/step
# Epoch 92/100
# 4688/4688 - 23s - loss: 0.0679 - accuracy: 0.9816 - val_loss: 0.0603 - val_accuracy: 0.9836 - 23s/epoch - 5ms/step
# Epoch 93/100
# 4688/4688 - 23s - loss: 0.0680 - accuracy: 0.9816 - val_loss: 0.0598 - val_accuracy: 0.9838 - 23s/epoch - 5ms/step
# Epoch 94/100
# 4688/4688 - 22s - loss: 0.0680 - accuracy: 0.9816 - val_loss: 0.0601 - val_accuracy: 0.9840 - 22s/epoch - 5ms/step
# Epoch 95/100
# 4688/4688 - 24s - loss: 0.0679 - accuracy: 0.9816 - val_loss: 0.0594 - val_accuracy: 0.9842 - 24s/epoch - 5ms/step
# Epoch 96/100
# 4688/4688 - 23s - loss: 0.0678 - accuracy: 0.9817 - val_loss: 0.0595 - val_accuracy: 0.9841 - 23s/epoch - 5ms/step
# Epoch 97/100
# 4688/4688 - 22s - loss: 0.0679 - accuracy: 0.9817 - val_loss: 0.0604 - val_accuracy: 0.9839 - 22s/epoch - 5ms/step
# Epoch 98/100
# 4688/4688 - 23s - loss: 0.0679 - accuracy: 0.9816 - val_loss: 0.0602 - val_accuracy: 0.9838 - 23s/epoch - 5ms/step
# Epoch 99/100
# 4688/4688 - 24s - loss: 0.0680 - accuracy: 0.9816 - val_loss: 0.0599 - val_accuracy: 0.9839 - 24s/epoch - 5ms/step
# Epoch 100/100
# 4688/4688 - 23s - loss: 0.0679 - accuracy: 0.9817 - val_loss: 0.0593 - val_accuracy: 0.9841 - 23s/epoch - 5ms/step

# %%
#5 rd model for stack
initializer = tf.keras.initializers.GlorotUniform(seed=33)
constraints = None

model_5 = tf.keras.Sequential([
      tf.keras.layers.Dense(256, input_dim=x_train.shape[1], kernel_initializer=initializer, activation='relu',name='dense_5a'),
      tf.keras.layers.Dense(128, input_dim=x_train.shape[1], kernel_initializer=initializer, activation='relu',name='dense_5b'),
      tf.keras.layers.Dropout(0.3),
      tf.keras.layers.Dense(128, input_dim=x_train.shape[1], kernel_initializer=initializer, activation='relu',name='dense_5c'),
      tf.keras.layers.Dropout(0.3),
      tf.keras.layers.Dense(64, input_dim=x_train.shape[1], kernel_initializer=initializer, activation='relu',name='dense_5d'),
      tf.keras.layers.Dense(y_train_enforce.shape[1],activation='softmax')
      ])

# %%
model_5.compile(loss='binary_crossentropy',metrics=['accuracy'], optimizer='adam')

log_dir_5 = colab_model_write_path + "model_5" + datetime.now().strftime("%Y%m%d%H%M%S")

monitor_5 = [
            tf.keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=1e-5, patience=100, verbose=1, mode='auto',restore_best_weights=True),
            tf.keras.callbacks.TensorBoard(log_dir=log_dir_5, histogram_freq=1)
        ]
history_5  = model_5.fit(x_train,y_train_enforce,validation_data=(x_test,y_test_enforce), callbacks=[monitor_5],verbose=2, batch_size=512, epochs=100)
model_5.save(colab_model_write_path + 'model5.h5')
# Out:
# Epoch 1/100
# 4688/4688 - 27s - loss: 0.0027 - accuracy: 0.9992 - val_loss: 0.0016 - val_accuracy: 0.9994 - 27s/epoch - 6ms/step
# Epoch 2/100
# 4688/4688 - 24s - loss: 0.0016 - accuracy: 0.9994 - val_loss: 0.0015 - val_accuracy: 0.9994 - 24s/epoch - 5ms/step
# Epoch 3/100
# 4688/4688 - 25s - loss: 0.0015 - accuracy: 0.9994 - val_loss: 0.0014 - val_accuracy: 0.9995 - 25s/epoch - 5ms/step
# Epoch 4/100
# 4688/4688 - 24s - loss: 0.0015 - accuracy: 0.9995 - val_loss: 0.0014 - val_accuracy: 0.9995 - 24s/epoch - 5ms/step
# Epoch 5/100
# 4688/4688 - 25s - loss: 0.0014 - accuracy: 0.9995 - val_loss: 0.0014 - val_accuracy: 0.9995 - 25s/epoch - 5ms/step
# Epoch 6/100
# 4688/4688 - 25s - loss: 0.0014 - accuracy: 0.9995 - val_loss: 0.0015 - val_accuracy: 0.9995 - 25s/epoch - 5ms/step
# Epoch 7/100
# 4688/4688 - 25s - loss: 0.0013 - accuracy: 0.9995 - val_loss: 0.0014 - val_accuracy: 0.9995 - 25s/epoch - 5ms/step
# Epoch 8/100
# 4688/4688 - 25s - loss: 0.0013 - accuracy: 0.9995 - val_loss: 0.0015 - val_accuracy: 0.9995 - 25s/epoch - 5ms/step
# Epoch 9/100
# 4688/4688 - 25s - loss: 0.0013 - accuracy: 0.9995 - val_loss: 0.0015 - val_accuracy: 0.9995 - 25s/epoch - 5ms/step
# Epoch 10/100
# 4688/4688 - 25s - loss: 0.0012 - accuracy: 0.9995 - val_loss: 0.0014 - val_accuracy: 0.9995 - 25s/epoch - 5ms/step
# Epoch 11/100
# 4688/4688 - 24s - loss: 0.0012 - accuracy: 0.9995 - val_loss: 0.0017 - val_accuracy: 0.9994 - 24s/epoch - 5ms/step
# Epoch 12/100
# 4688/4688 - 25s - loss: 0.0012 - accuracy: 0.9995 - val_loss: 0.0015 - val_accuracy: 0.9995 - 25s/epoch - 5ms/step
# Epoch 13/100
# 4688/4688 - 32s - loss: 0.0012 - accuracy: 0.9996 - val_loss: 0.0020 - val_accuracy: 0.9994 - 32s/epoch - 7ms/step
# Epoch 14/100
# 4688/4688 - 25s - loss: 0.0012 - accuracy: 0.9996 - val_loss: 0.0019 - val_accuracy: 0.9994 - 25s/epoch - 5ms/step
# Epoch 15/100
# 4688/4688 - 25s - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.0027 - val_accuracy: 0.9995 - 25s/epoch - 5ms/step
# Epoch 16/100
# 4688/4688 - 25s - loss: 0.0012 - accuracy: 0.9996 - val_loss: 0.0025 - val_accuracy: 0.9994 - 25s/epoch - 5ms/step
# Epoch 17/100
# 4688/4688 - 35s - loss: 0.0012 - accuracy: 0.9996 - val_loss: 0.0017 - val_accuracy: 0.9994 - 35s/epoch - 8ms/step
# Epoch 18/100
# 4688/4688 - 25s - loss: 0.0012 - accuracy: 0.9996 - val_loss: 0.0022 - val_accuracy: 0.9994 - 25s/epoch - 5ms/step
# Epoch 19/100
# 4688/4688 - 24s - loss: 0.0011 - accuracy: 0.9996 - val_loss: 0.0018 - val_accuracy: 0.9994 - 24s/epoch - 5ms/step
# Epoch 20/100
# 4688/4688 - 25s - loss: 0.0011 - accuracy: 0.9996 - val_loss: 0.0034 - val_accuracy: 0.9994 - 25s/epoch - 5ms/step
# Epoch 21/100
# 4688/4688 - 25s - loss: 0.0012 - accuracy: 0.9996 - val_loss: 0.0021 - val_accuracy: 0.9995 - 25s/epoch - 5ms/step
# Epoch 22/100
# 4688/4688 - 25s - loss: 0.0011 - accuracy: 0.9996 - val_loss: 0.0023 - val_accuracy: 0.9995 - 25s/epoch - 5ms/step
# Epoch 23/100
# 4688/4688 - 43s - loss: 0.0011 - accuracy: 0.9996 - val_loss: 0.0026 - val_accuracy: 0.9994 - 43s/epoch - 9ms/step
# Epoch 24/100
# 4688/4688 - 25s - loss: 0.0011 - accuracy: 0.9996 - val_loss: 0.0039 - val_accuracy: 0.9994 - 25s/epoch - 5ms/step
# Epoch 25/100
# 4688/4688 - 33s - loss: 0.0011 - accuracy: 0.9996 - val_loss: 0.0050 - val_accuracy: 0.9994 - 33s/epoch - 7ms/step
# Epoch 26/100
# 4688/4688 - 24s - loss: 0.0012 - accuracy: 0.9996 - val_loss: 0.0041 - val_accuracy: 0.9994 - 24s/epoch - 5ms/step
# Epoch 27/100
# 4688/4688 - 25s - loss: 0.0011 - accuracy: 0.9996 - val_loss: 0.0075 - val_accuracy: 0.9994 - 25s/epoch - 5ms/step
# Epoch 28/100
# 4688/4688 - 25s - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.0026 - val_accuracy: 0.9994 - 25s/epoch - 5ms/step
# Epoch 29/100
# 4688/4688 - 25s - loss: 0.0010 - accuracy: 0.9996 - val_loss: 0.0033 - val_accuracy: 0.9994 - 25s/epoch - 5ms/step
# Epoch 30/100
# 4688/4688 - 25s - loss: 0.0011 - accuracy: 0.9996 - val_loss: 0.0024 - val_accuracy: 0.9994 - 25s/epoch - 5ms/step
# Epoch 31/100
# 4688/4688 - 25s - loss: 0.0010 - accuracy: 0.9996 - val_loss: 0.0078 - val_accuracy: 0.9994 - 25s/epoch - 5ms/step
# Epoch 32/100
# 4688/4688 - 24s - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0051 - val_accuracy: 0.9994 - 24s/epoch - 5ms/step
# Epoch 33/100
# 4688/4688 - 24s - loss: 9.9268e-04 - accuracy: 0.9997 - val_loss: 0.0054 - val_accuracy: 0.9994 - 24s/epoch - 5ms/step
# Epoch 34/100
# 4688/4688 - 26s - loss: 9.8015e-04 - accuracy: 0.9997 - val_loss: 0.0051 - val_accuracy: 0.9994 - 26s/epoch - 6ms/step
# Epoch 35/100
# 4688/4688 - 25s - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0076 - val_accuracy: 0.9994 - 25s/epoch - 5ms/step
# Epoch 36/100
# 4688/4688 - 26s - loss: 9.8938e-04 - accuracy: 0.9997 - val_loss: 0.0100 - val_accuracy: 0.9994 - 26s/epoch - 5ms/step
# Epoch 37/100
# 4688/4688 - 24s - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.
- val_accuracy: 0.9994 - 25s/epoch - 5ms/step
# Epoch 70/100
# 4688/4688 - 25s - loss: 8.5749e-04 - accuracy: 0.9997 - val_loss: 0.0240 - val_accuracy: 0.9994 - 25s/epoch - 5ms/step
# Epoch 71/100
# 4688/4688 - 25s - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0430 - val_accuracy: 0.9994 - 25s/epoch - 5ms/step
# Epoch 72/100
# 4688/4688 - 25s - loss: 9.6441e-04 - accuracy: 0.9998 - val_loss: 0.0379 - val_accuracy: 0.9994 - 25s/epoch - 5ms/step
# Epoch 73/100
# 4688/4688 - 25s - loss: 9.9094e-04 - accuracy: 0.9997 - val_loss: 0.0419 - val_accuracy: 0.9994 - 25s/epoch - 5ms/step
# Epoch 74/100
# 4688/4688 - 25s - loss: 7.9258e-04 - accuracy: 0.9998 - val_loss: 0.0646 - val_accuracy: 0.9994 - 25s/epoch - 5ms/step
# Epoch 75/100
# 4688/4688 - 25s - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0226 - val_accuracy: 0.9994 - 25s/epoch - 5ms/step
# Epoch 76/100
# 4688/4688 - 25s - loss: 9.5434e-04 - accuracy: 0.9997 - val_loss: 0.0354 - val_accuracy: 0.9995 - 25s/epoch - 5ms/step
# Epoch 77/100
# 4688/4688 - 26s - loss: 8.5588e-04 - accuracy: 0.9998 - val_loss: 0.0919 - val_accuracy: 0.9994 - 26s/epoch - 5ms/step
# Epoch 78/100
# 4688/4688 - 25s - loss: 9.4485e-04 - accuracy: 0.9998 - val_loss: 0.0496 - val_accuracy: 0.9994 - 25s/epoch - 5ms/step
# Epoch 79/100
# 4688/4688 - 25s - loss: 8.4635e-04 - accuracy: 0.9998 - val_loss: 0.0655 - val_accuracy: 0.9994 - 25s/epoch - 5ms/step
# Epoch 80/100
# 4688/4688 - 25s - loss: 8.8400e-04 - accuracy: 0.9998 - val_loss: 0.0737 - val_accuracy: 0.9994 - 25s/epoch - 5ms/step
# Epoch 81/100
# 4688/4688 - 25s - loss: 8.1012e-04 - accuracy: 0.9998 - val_loss: 0.0616 - val_accuracy: 0.9994 - 25s/epoch - 5ms/step
# Epoch 82/100
# 4688/4688 - 24s - loss: 8.4598e-04 - accuracy: 0.9998 - val_loss: 0.0587 - val_accuracy: 0.9995 - 24s/epoch - 5ms/step
# Epoch 83/100
# 4688/4688 - 24s - loss: 8.6304e-04 - accuracy: 0.9998 - val_loss: 0.0609 - val_accuracy: 0.9995 - 24s/epoch - 5ms/step
# Epoch 84/100
# 4688/4688 - 26s - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.1015 - val_accuracy: 0.9994 - 26s/epoch - 6ms/step
# Epoch 85/100
# 4688/4688 - 25s - loss: 0.0021 - accuracy: 0.9998 - val_loss: 0.0530 - val_accuracy: 0.9994 - 25s/epoch - 5ms/step
# Epoch 86/100
# 4688/4688 - 25s - loss: 0.0017 - accuracy: 0.9998 - val_loss: 0.0743 - val_accuracy: 0.9994 - 25s/epoch - 5ms/step
# Epoch 87/100
# 4688/4688 - 26s - loss: 8.2021e-04 - accuracy: 0.9998 - val_loss: 0.0907 - val_accuracy: 0.9994 - 26s/epoch - 5ms/step
# Epoch 88/100
# 4688/4688 - 25s - loss: 9.8008e-04 - accuracy: 0.9998 - val_loss: 0.1160 - val_accuracy: 0.9994 - 25s/epoch - 5ms/step
# Epoch 89/100
# 4688/4688 - 25s - loss: 9.0575e-04 - accuracy: 0.9998 - val_loss: 0.0843 - val_accuracy: 0.9994 - 25s/epoch - 5ms/step
# Epoch 90/100
# 4688/4688 - 25s - loss: 0.0013 - accuracy: 0.9998 - val_loss: 0.0563 - val_accuracy: 0.9994 - 25s/epoch - 5ms/step
# Epoch 91/100
# 4688/4688 - 26s - loss: 0.0010 - accuracy: 0.9998 - val_loss: 0.0429 - val_accuracy: 0.9994 - 26s/epoch - 5ms/step
# Epoch 92/100
# 4688/4688 - 24s - loss: 9.5254e-04 - accuracy: 0.9998 - val_loss: 0.1159 - val_accuracy: 0.9994 - 24s/epoch - 5ms/step
# Epoch 93/100
# 4688/4688 - 25s - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.1126 - val_accuracy: 0.9994 - 25s/epoch - 5ms/step
# Epoch 94/100
# 4688/4688 - 25s - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.1009 - val_accuracy: 0.9994 - 25s/epoch - 5ms/step
# Epoch 95/100
# 4688/4688 - 25s - loss: 0.0049 - accuracy: 0.9998 - val_loss: 0.1238 - val_accuracy: 0.9992 - 25s/epoch - 5ms/step
# Epoch 96/100
# 4688/4688 - 25s - loss: 8.4554e-04 - accuracy: 0.9998 - val_loss: 0.0852 - val_accuracy: 0.9994 - 25s/epoch - 5ms/step
# Epoch 97/100
# 4688/4688 - 28s - loss: 8.6777e-04 - accuracy: 0.9998 - val_loss: 0.0740 - val_accuracy: 0.9994 - 28s/epoch - 6ms/step
# Epoch 98/100
# 4688/4688 - 25s - loss: 9.6080e-04 - accuracy: 0.9998 - val_loss: 0.1114 - val_accuracy: 0.9994 - 25s/epoch - 5ms/step
# Epoch 99/100
# 4688/4688 - 25s - loss: 9.0124e-04 - accuracy: 0.9998 - val_loss: 0.1640 - val_accuracy: 0.9994 - 25s/epoch - 5ms/step
# Epoch 100/100
# 4688/4688 - 25s - loss: 0.0012 - accuracy: 0.9998 - val_loss: 0.1074 - val_accuracy: 0.9994 - 25s/epoch - 5ms/step

# %%
model_1.save(colab_model_write_path + 'model1_1.h5')
model_2.save(colab_model_write_path + 'model1_2.h5')
model_3.save(colab_model_write_path + 'model1_3.h5')
model_4.save(colab_model_write_path + 'model1_4.h5')
model_5.save(colab_model_write_path + 'model1_5.h5')

# %% [markdown]
# # Model 6 SMOTE

# %%
from collections import Counter
#type(y_train)
ydp= pd.DataFrame(y_train)
ydp = tf.argmax(ydp, axis=1)
#ydp = pd.DataFrame(ydp)
#ydp.value_counts
dicts = Counter(ydp.numpy())
dicts
# Out:
# Counter({5: 687357,
#          2: 794288,
#          19: 119905,
#          15: 21686,
#          6: 564557,
#          4: 4025,
#          11: 82731,
#          20: 77617,
#          17: 36205,
#          3: 4569,
#          10: 3752,
#          9: 542,
#          7: 968,
#          8: 694,
#          1: 575,
#          16: 239,
#          0: 81,
#          18: 94,
#          13: 69,
#          12: 42,
#          14: 4})

# %%
#from imblearn.over_sampling import SMOTE
#smote = SMOTE(random_state=42)
#X_train_over,y_train_over = smote.fit_resample(x_train,y_train)
from collections import Counter
from sklearn.datasets import make_classification
from imblearn.over_sampling import SMOTE


MININUM_SAMPLES = 30000
MAXINUM_SAMPLES = 300000

# sample_dict = {5: 687357,
#          2: 794288,
#          19: 119905,
#          15: 21686,
#          6: 564557,
#          4: 4025,
#          11: 82731,
#          20: 77617,
#          17: 36205,
#          3: 4569,
#          10: 3752,
#          9: 542,
#          7: 968,
#          8: 694,
#          1: 575,
#          16: 239,
#          0: 81,
#          18: 94,
#          13: 69,
#          12: 42,
#          14: 4}

sample_dict = {5: 687357,
         2: 794288,
         19: 119905,
         15: 21686,
         6: 564557,
         4: 4025,
         11: 82731,
         20: 77617,
         17: 36205,
         3: 4569,
         10: 3752,
         9: 542,
         7: 968,
         8: 694,
         1: 575,
         16: 239,
         0: 81,
         18: 94,
         13: 69,
         12: 42,
         14: 4}

from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler

#ros = RandomOverSampler(random_state=33)
for i in range(21):
  if sample_dict[i] >  MAXINUM_SAMPLES:
    sample_dict[i] =  MAXINUM_SAMPLES

ros = RandomUnderSampler(sampling_strategy = sample_dict, random_state=33)
X_train_under, y_train_under = ros.fit_resample(x_train, y_train)

# for i in range(21):
#   if sample_dict[i] <  16:
#     sample_dict[i] =  16

# ros = RandomOverSampler(sampling_strategy = sample_dict, random_state=33)
# X_train_over, y_train_over = ros.fit_resample(x_train, y_train)

for i in range(21):
  if sample_dict[i] <  MININUM_SAMPLES:
    sample_dict[i] =  MININUM_SAMPLES

ros = RandomOverSampler(sampling_strategy = sample_dict, random_state=33)
X_train_over, y_train_over = ros.fit_resample(X_train_under, y_train_under)

# sm = SMOTE(sampling_strategy = sample_dict, random_state=33)
# X_train_over, y_train_over = sm.fit_resample(X_train_over, y_train_over)
print('SMOTE 적용 전 학습용 피처/레이블 데이터 세트: ', x_train.shape, y_train.shape)
print('SMOTE 적용 후 학습용 피처/레이블 데이터 세트: ', X_train_over.shape, y_train_over.shape)
# Out:
# SMOTE 적용 전 학습용 피처/레이블 데이터 세트:  (2400000, 127) (2400000, 21)
# SMOTE 적용 후 학습용 피처/레이블 데이터 세트:  (1636458, 127) (1636458, 21)

# %%
import gc


gc.collect()
# Out:
# 3895

# %%
#6 rd model for stack
initializer = tf.keras.initializers.GlorotUniform(seed=33)
constraints = None

#6 rd model for stack
model_6 = tf.keras.Sequential([
      tf.keras.layers.Dense(256, input_dim=X_train_over.shape[1], kernel_initializer=initializer, activation='relu',name='dense_6a'),
      tf.keras.layers.Dropout(0.3),
      tf.keras.layers.Dense(128, input_dim=X_train_over.shape[1], kernel_initializer=initializer, activation='relu',name='dense_6b'),
      tf.keras.layers.Dropout(0.2),
      tf.keras.layers.Dense(128, input_dim=X_train_over.shape[1], kernel_initializer=initializer, activation='relu',name='dense_6c'),
      tf.keras.layers.Dropout(0.1),
      tf.keras.layers.Dense(64, input_dim=X_train_over.shape[1], kernel_initializer=initializer, activation='relu',name='dense_6d'),
      tf.keras.layers.Dense(y_train_over.shape[1],activation='softmax')
      ])

# %%
model_6.compile(loss='categorical_crossentropy',metrics=['accuracy'], optimizer='adam')

log_dir_6 = colab_model_write_path + "model_6" + datetime.now().strftime("%Y%m%d%H%M%S")

monitor_6 = [
            tf.keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=1e-7, patience=100, verbose=1, mode='auto',restore_best_weights=True),
            tf.keras.callbacks.TensorBoard(log_dir=log_dir_6, histogram_freq=1)
        ]
history_6  = model_6.fit(X_train_over,y_train_over,validation_data=(x_test,y_test), callbacks=[monitor_6],verbose=2, batch_size=512, epochs=100)
model_6.save(colab_model_write_path + 'model1_6.h5')
# Out:
# Epoch 1/100
# 3197/3197 - 31s - loss: 0.3034 - accuracy: 0.9018 - val_loss: 0.1357 - val_accuracy: 0.9645 - 31s/epoch - 10ms/step
# Epoch 2/100
# 3197/3197 - 30s - loss: 0.1813 - accuracy: 0.9432 - val_loss: 0.1127 - val_accuracy: 0.9690 - 30s/epoch - 9ms/step
# Epoch 3/100
# 3197/3197 - 23s - loss: 0.1597 - accuracy: 0.9504 - val_loss: 0.1126 - val_accuracy: 0.9698 - 23s/epoch - 7ms/step
# Epoch 4/100
# 3197/3197 - 28s - loss: 0.1493 - accuracy: 0.9537 - val_loss: 0.1081 - val_accuracy: 0.9715 - 28s/epoch - 9ms/step
# Epoch 5/100
# 3197/3197 - 32s - loss: 0.1428 - accuracy: 0.9559 - val_loss: 0.1061 - val_accuracy: 0.9718 - 32s/epoch - 10ms/step
# Epoch 6/100
# 3197/3197 - 23s - loss: 0.1384 - accuracy: 0.9574 - val_loss: 0.1098 - val_accuracy: 0.9735 - 23s/epoch - 7ms/step
# Epoch 7/100
# 3197/3197 - 30s - loss: 0.1344 - accuracy: 0.9586 - val_loss: 0.1007 - val_accuracy: 0.9735 - 30s/epoch - 9ms/step
# Epoch 8/100
# 3197/3197 - 23s - loss: 0.1320 - accuracy: 0.9594 - val_loss: 0.1004 - val_accuracy: 0.9751 - 23s/epoch - 7ms/step
# Epoch 9/100
# 3197/3197 - 23s - loss: 0.1295 - accuracy: 0.9602 - val_loss: 0.0994 - val_accuracy: 0.9747 - 23s/epoch - 7ms/step
# Epoch 10/100
# 3197/3197 - 24s - loss: 0.1277 - accuracy: 0.9606 - val_loss: 0.0992 - val_accuracy: 0.9753 - 24s/epoch - 8ms/step
# Epoch 11/100
# Epoch 100/100
# 3197/3197 - 28s - loss: 0.1004 - accuracy: 0.9689 - val_loss: 0.0792 - val_accuracy: 0.9794 - 28s/epoch - 9ms/step

# %%
colab_model_write_path
model_6.save(colab_model_write_path + 'model1_6.h5')

# %% [markdown]
# # Ensemble Model
# https://abstractask.tistory.com/105
#
# Model #1, Model #2, Model #3, + OverSampling/UnderSampling

# %%
colab_write_path = "/home/marius1406/"
colab_model_write_path = colab_write_path + "202310120135/"
print("colab_write_path=" + colab_write_path)
print("colab_model_write_path=" + colab_model_write_path)
# Out:
# colab_write_path=/home/marius1406/
# colab_model_write_path=/home/marius1406/202310120135/

# %% [markdown]
# ### SM

# %%
# load models from file
# for both logistic and nueral
def load_SM_models(n_models):
	all_models = list()

	for i in range(n_models):
		if i != 4 and i != 3: #Model4와 Binary 배제
			filename = colab_model_write_path + 'model1_' + str(i + 1) + '.h5'
			# load model from file
			model = load_model(filename,custom_objects=None)
			# add to list of members
			all_models.append(model)
			print('>loaded %s' % filename)
	return all_models

# %%
# define stacked model from multiple member input models
#neural

def define_stacked_model(members):
	initializer = tf.keras.initializers.GlorotUniform(seed=64)
	constraints = None

  # update all layers in all models to not be trainable
	for i in range(len(members)):
		model = members[i]
		for layer in model.layers:
			# make not trainable
			layer.trainable = False
			# rename to avoid 'unique layer name' issue
			layer._name = 'ensemble_' + str(i + 1) + '_' + layer.name


	# define multi-headed input
	ensemble_visible = [model.input for model in members]
	# concatenate merge output from each model
	ensemble_outputs = [model.output for model in members]
	merge = concatenate(ensemble_outputs)
	merge = Dense(128, kernel_initializer=initializer, activation='relu',name="dense_ea")(merge)
	merge = Dense(128, kernel_initializer=initializer, activation='relu',name="dense_eb")(merge)
	output = Dense(Y.shape[1], kernel_initializer=initializer, activation='softmax',name="dense_ec")(merge)
	model = Model(inputs=ensemble_visible, outputs=output)
	# plot graph of ensemble
	plot_model(model, show_shapes=True, to_file='model_graph.png')
	# compile
	model.summary()
	model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
	return model

# %%
# fit a stacked model
#neural
from datetime import timedelta, datetime

#colab_path = "gdrive/My Drive/Colab Notebooks/Network/models/"
log_dir = colab_model_write_path + "model_7" + datetime.now().strftime("%Y%m%d%H%M%S")

monitor_7= [
             tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)
            ]

def fit_stacked_model(model, inputX, inputy_enc):
	# prepare input data
	X = [inputX for _ in range(len(model.input))]
	# encode output data
#	inputy_enc = to_categorical(inputy)
	# fit model
	history_7=model.fit(X, inputy_enc, epochs=60, verbose=2,callbacks=[monitor_7])

# %%
# make a prediction with a stacked model
#neural
def predict_stacked_model(model, inputX):
	# prepare input data
	X = [inputX for _ in range(len(model.input))]
	# make prediction
	return model.predict(X, verbose=2)

# %%
# load all models
#neural
from keras.models import load_model
n_members = 6
members = load_SM_models(n_members)
print('Loaded %d models' % len(members))
# Out:
# >loaded /home/marius1406/202310120135/model1_1.h5
# >loaded /home/marius1406/202310120135/model1_2.h5
# >loaded /home/marius1406/202310120135/model1_3.h5
# >loaded /home/marius1406/202310120135/model1_6.h5
# Loaded 4 models

# %%
# define ensemble model
import matplotlib.pyplot as plt
#from keras.utils import plot_model
#neural
#from keras.layers.merge import concatenate
from keras.layers import concatenate
from keras.layers import Dense
from keras.models import Model
from tensorflow.keras.utils import plot_model

stacked_model = define_stacked_model(members)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  dense_2a_input (InputLayer)    [(None, 127)]        0           []
#
#  dense_3a_input (InputLayer)    [(None, 127)]        0           []
#
#  dense_6a_input (InputLayer)    [(None, 127)]        0           []
#
#  dense_1a_input (InputLayer)    [(None, 127)]        0           []
#
#  ensemble_2_dense_2a (Dense)    (None, 64)           8192        ['dense_2a_input[0][0]']
#
#  ensemble_3_dense_3a (Dense)    (None, 512)          65536       ['dense_3a_input[0][0]']
#
#  ensemble_4_dense_6a (Dense)    (None, 256)          32768       ['dense_6a_input[0][0]']
#
#  ensemble_1_dense_1a (Dense)    (None, 64)           8192        ['dense_1a_input[0][0]']
#
#  ensemble_2_dense_2b (Dense)    (None, 128)          8320        ['ensemble_2_dense_2a[0][0]']
#
#  ensemble_3_dropout_5 (Dropout)  (None, 512)         0           ['ensemble_3_dense_3a[0][0]']
#
#  ensemble_4_dropout_13 (Dropout  (None, 256)         0           ['ensemble_4_dense_6a[0][0]']
#  )
#
#  ensemble_1_dense_1b (Dense)    (None, 128)          8320        ['ensemble_1_dense_1a[0][0]']
#
#  ensemble_2_dropout_2 (Dropout)  (None, 128)         0           ['ensemble_2_dense_2b[0][0]']
#
#  ensemble_3_dense_3b (Dense)    (None, 256)          131328      ['ensemble_3_dropout_5[0][0]']
#
#  ensemble_4_dense_6b (Dense)    (None, 128)          32896       ['ensemble_4_dropout_13[0][0]']
#
#  ensemble_1_dropout (Dropout)   (None, 128)          0           ['ensemble_1_dense_1b[0][0]']
#
#  ensemble_2_dense_2c (Dense)    (None, 256)          33024       ['ensemble_2_dropout_2[0][0]']
#
#  ensemble_3_dropout_6 (Dropout)  (None, 256)         0           ['ensemble_3_dense_3b[0][0]']
#
#  ensemble_4_dropout_14 (Dropout  (None, 128)         0           ['ensemble_4_dense_6b[0][0]']
#  )
#
#  ensemble_1_dense_1c (Dense)    (None, 128)          16512       ['ensemble_1_dropout[0][0]']
#
#  ensemble_2_dropout_3 (Dropout)  (None, 256)         0           ['ensemble_2_dense_2c[0][0]']
#
#  ensemble_3_dense_3c (Dense)    (None, 128)          32896       ['ensemble_3_dropout_6[0][0]']
#
#  ensemble_4_dense_6c (Dense)    (None, 128)          16512       ['ensemble_4_dropout_14[0][0]']
#
#  ensemble_1_dropout_1 (Dropout)  (None, 128)         0           ['ensemble_1_dense_1c[0][0]']
#
#  ensemble_2_dense_2d (Dense)    (None, 128)          32896       ['ensemble_2_dropout_3[0][0]']
#
#  ensemble_3_dropout_7 (Dropout)  (None, 128)         0           ['ensemble_3_dense_3c[0][0]']
#
#  ensemble_4_dropout_15 (Dropout  (None, 128)         0           ['ensemble_4_dense_6c[0][0]']
#  )
#
#  ensemble_1_dense_1d (Dense)    (None, 64)           8256        ['ensemble_1_dropout_1[0][0]']
#
#  ensemble_2_dropout_4 (Dropout)  (None, 128)         0           ['ensemble_2_dense_2d[0][0]']
#
#  ensemble_3_dense_3d (Dense)    (None, 128)          16512       ['ensemble_3_dropout_7[0][0]']
#
#  ensemble_4_dense_6d (Dense)    (None, 64)           8256        ['ensemble_4_dropout_15[0][0]']
#
#  ensemble_1_dense (Dense)       (None, 21)           1365        ['ensemble_1_dense_1d[0][0]']
#
#  ensemble_2_dense_1 (Dense)     (None, 21)           2709        ['ensemble_2_dropout_4[0][0]']
#
#  ensemble_3_dense_2 (Dense)     (None, 21)           2709        ['ensemble_3_dense_3d[0][0]']
#
#  ensemble_4_dense_5 (Dense)     (None, 21)           1365        ['ensemble_4_dense_6d[0][0]']
#
#  concatenate (Concatenate)      (None, 84)           0           ['ensemble_1_dense[0][0]',
#                                                                   'ensemble_2_dense_1[0][0]',
#                                                                   'ensemble_3_dense_2[0][0]',
#                                                                   'ensemble_4_dense_5[0][0]']
#
#  dense_ea (Dense)               (None, 128)          10880       ['concatenate[0][0]']
#
#  dense_eb (Dense)               (None, 128)          16512       ['dense_ea[0][0]']
#
#  dense_ec (Dense)               (None, 21)           2709        ['dense_eb[0][0]']
#
# ==================================================================================================
# Total params: 498,665
# Trainable params: 30,101
# Non-trainable params: 468,564
# __________________________________________________________________________________________________

# %%
from keras.utils import to_categorical
fit_stacked_model(stacked_model, x_train,y_train)
stacked_model.save(colab_model_write_path + 'stacked_model_SM.h5')
# Out:
# Epoch 1/60
# 75000/75000 - 199s - loss: 0.0605 - accuracy: 0.9849 - 199s/epoch - 3ms/step
# Epoch 2/60
# 75000/75000 - 195s - loss: 0.0572 - accuracy: 0.9852 - 195s/epoch - 3ms/step
# Epoch 3/60
# 75000/75000 - 191s - loss: 0.0569 - accuracy: 0.9853 - 191s/epoch - 3ms/step
# Epoch 4/60
# 75000/75000 - 208s - loss: 0.0570 - accuracy: 0.9853 - 208s/epoch - 3ms/step
# Epoch 5/60
# 75000/75000 - 197s - loss: 0.0571 - accuracy: 0.9853 - 197s/epoch - 3ms/step
# Epoch 6/60
# 75000/75000 - 198s - loss: 0.0574 - accuracy: 0.9853 - 198s/epoch - 3ms/step
# Epoch 7/60
# 75000/75000 - 195s - loss: 0.0572 - accuracy: 0.9853 - 195s/epoch - 3ms/step
# Epoch 8/60
# 75000/75000 - 189s - loss: 0.0577 - accuracy: 0.9852 - 189s/epoch - 3ms/step
# Epoch 9/60
# 75000/75000 - 188s - loss: 0.0583 - accuracy: 0.9852 - 188s/epoch - 3ms/step
# Epoch 10/60
# 75000/75000 - 189s - loss: 0.0586 - accuracy: 0.9852 - 189s/epoch - 3ms/step
# Epoch 11/60
# 75000/75000 - 188s - loss: 0.0587 - accuracy: 0.9853 - 188s/epoch - 3ms/step
# Epoch 12/60
# 75000/75000 - 189s - loss: 0.0589 - accuracy: 0.9853 - 189s/epoch - 3ms/step
# Epoch 13/60
# 75000/75000 - 189s - loss: 0.0591 - accuracy: 0.9852 - 189s/epoch - 3ms/step
# Epoch 14/60
# 75000/75000 - 187s - loss: 0.0597 - accuracy: 0.9852 - 187s/epoch - 2ms/step
# Epoch 15/60
# 75000/75000 - 190s - loss: 0.0594 - accuracy: 0.9852 - 190s/epoch - 3ms/step
# Epoch 16/60
# 75000/75000 - 191s - loss: 0.0590 - accuracy: 0.9852 - 191s/epoch - 3ms/step
# Epoch 17/60
# 75000/75000 - 193s - loss: 0.0599 - accuracy: 0.9852 - 193s/epoch - 3ms/step
# Epoch 18/60
# 75000/75000 - 191s - loss: 0.0601 - accuracy: 0.9851 - 191s/epoch - 3ms/step
# Epoch 19/60
# 75000/75000 - 189s - loss: 0.0599 - accuracy: 0.9851 - 189s/epoch - 3ms/step
# Epoch 20/60
# 75000/75000 - 188s - loss: 0.0613 - accuracy: 0.9851 - 188s/epoch - 3ms/step
# Epoch 21/60
# 75000/75000 - 189s - loss: 0.0635 - accuracy: 0.9851 - 189s/epoch - 3ms/step
# Epoch 22/60
# 75000/75000 - 189s - loss: 0.0621 - accuracy: 0.9851 - 189s/epoch - 3ms/step
# Epoch 23/60
# 75000/75000 - 188s - loss: 0.0606 - accuracy: 0.9851 - 188s/epoch - 3ms/step
# Epoch 24/60
# 75000/75000 - 189s - loss: 0.0603 - accuracy: 0.9851 - 189s/epoch - 3ms/step
# Epoch 25/60
# 75000/75000 - 189s - loss: 0.0605 - accuracy: 0.9850 - 189s/epoch - 3ms/step
# Epoch 26/60
# 75000/75000 - 188s - loss: 0.0639 - accuracy: 0.9850 - 188s/epoch - 3ms/step
# Epoch 27/60
# 75000/75000 - 189s - loss: 0.0617 - accuracy: 0.9850 - 189s/epoch - 3ms/step
# Epoch 28/60
# 75000/75000 - 188s - loss: 0.0620 - accuracy: 0.9850 - 188s/epoch - 3ms/step
# Epoch 29/60
# 75000/75000 - 189s - loss: 0.0615 - accuracy: 0.9850 - 189s/epoch - 3ms/step
# Epoch 30/60
# 75000/75000 - 189s - loss: 0.0636 - accuracy: 0.9849 - 189s/epoch - 3ms/step
# Epoch 31/60
# 75000/75000 - 189s - loss: 0.0642 - accuracy: 0.9850 - 189s/epoch - 3ms/step
# Epoch 32/60
# 75000/75000 - 189s - loss: 0.0652 - accuracy: 0.9850 - 189s/epoch - 3ms/step
# Epoch 33/60
# 75000/75000 - 187s - loss: 0.0669 - accuracy: 0.9849 - 187s/epoch - 2ms/step
# Epoch 34/60
# 75000/75000 - 188s - loss: 0.0657 - accuracy: 0.9850 - 188s/epoch - 3ms/step
# Epoch 35/60
# 75000/75000 - 188s - loss: 0.0658 - accuracy: 0.9850 - 188s/epoch - 3ms/step
# Epoch 36/60
# 75000/75000 - 188s - loss: 0.0630 - accuracy: 0.9849 - 188s/epoch - 3ms/step
# Epoch 37/60
# 75000/75000 - 190s - loss: 0.0637 - accuracy: 0.9850 - 190s/epoch - 3ms/step
# Epoch 38/60
# 75000/75000 - 189s - loss: 0.0708 - accuracy: 0.9849 - 189s/epoch - 3ms/step
# Epoch 39/60
# 75000/75000 - 189s - loss: 0.0698 - accuracy: 0.9849 - 189s/epoch - 3ms/step
# Epoch 40/60
# 75000/75000 - 188s - loss: 0.0687 - accuracy: 0.9849 - 188s/epoch - 3ms/step
# Epoch 41/60
# 75000/75000 - 188s - loss: 0.0692 - accuracy: 0.9849 - 188s/epoch - 3ms/step
# Epoch 42/60
# 75000/75000 - 189s - loss: 0.0655 - accuracy: 0.9849 - 189s/epoch - 3ms/step
# Epoch 43/60
# 75000/75000 - 189s - loss: 0.0692 - accuracy: 0.9849 - 189s/epoch - 3ms/step
# Epoch 44/60
# 75000/75000 - 190s - loss: 0.0650 - accuracy: 0.9849 - 190s/epoch - 3ms/step
# Epoch 45/60
# 75000/75000 - 189s - loss: 0.0673 - accuracy: 0.9848 - 189s/epoch - 3ms/step
# Epoch 46/60
# 75000/75000 - 188s - loss: 0.0690 - accuracy: 0.9849 - 188s/epoch - 3ms/step
# Epoch 47/60
# 75000/75000 - 189s - loss: 0.0735 - accuracy: 0.9848 - 189s/epoch - 3ms/step
# Epoch 48/60
# 75000/75000 - 190s - loss: 0.0643 - accuracy: 0.9848 - 190s/epoch - 3ms/step
# Epoch 49/60
# 75000/75000 - 189s - loss: 0.0715 - accuracy: 0.9848 - 189s/epoch - 3ms/step
# Epoch 50/60
# 75000/75000 - 189s - loss: 0.0717 - accuracy: 0.9848 - 189s/epoch - 3ms/step
# Epoch 51/60
# 75000/75000 - 189s - loss: 0.0661 - accuracy: 0.9848 - 189s/epoch - 3ms/step
# Epoch 52/60
# 75000/75000 - 188s - loss: 0.0661 - accuracy: 0.9847 - 188s/epoch - 3ms/step
# Epoch 53/60
# 75000/75000 - 188s - loss: 0.0648 - accuracy: 0.9848 - 188s/epoch - 3ms/step
# Epoch 54/60
# 75000/75000 - 188s - loss: 0.0683 - accuracy: 0.9848 - 188s/epoch - 3ms/step
# Epoch 55/60
# 75000/75000 - 189s - loss: 0.0643 - accuracy: 0.9848 - 189s/epoch - 3ms/step
# Epoch 56/60
# 75000/75000 - 189s - loss: 0.0670 - accuracy: 0.9848 - 189s/epoch - 3ms/step
# Epoch 57/60
# 75000/75000 - 190s - loss: 0.0703 - accuracy: 0.9847 - 190s/epoch - 3ms/step
# Epoch 58/60
# 75000/75000 - 189s - loss: 0.0672 - accuracy: 0.9848 - 189s/epoch - 3ms/step
# Epoch 59/60
# 75000/75000 - 189s - loss: 0.0678 - accuracy: 0.9848 - 189s/epoch - 3ms/step
# Epoch 60/60
# 75000/75000 - 190s - loss: 0.0699 - accuracy: 0.9847 - 190s/epoch - 3ms/step

# %% [markdown]
# ## Prediction & Evaluation

# %%
from sklearn.metrics import accuracy_score
import numpy as np
# make predictions and evaluate
#neural
yhat = predict_stacked_model(stacked_model, x_test_1)
yhat_val = tf.argmax(yhat, axis=1)
acc = accuracy_score(y_test_1, yhat_val)
print('Stacked Test Accuracy: %.4f' % acc)
# Out:
# 18750/18750 - 28s - 28s/epoch - 2ms/step
# Stacked Test Accuracy: 0.9851

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test_1, yhat_val))
classification_report(y_test_1, yhat_val)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        12
#            1       1.00      0.87      0.93       162
#            2       0.99      0.99      0.99    198477
#            3       1.00      1.00      1.00      1126
#            4       1.00      0.97      0.99       954
#            5       0.99      0.99      0.99    171544
#            6       0.99      0.99      0.99    141449
#            7       0.77      0.69      0.73       271
#            8       0.50      0.71      0.59       184
#            9       0.81      0.77      0.79       135
#           10       0.93      0.27      0.42       966
#           11       0.99      0.94      0.96     20974
#           12       0.56      0.50      0.53        10
#           13       0.87      0.76      0.81        17
#           14       0.00      0.00      0.00         2
#           15       0.89      0.77      0.83      5374
#           16       0.94      0.30      0.46        53
#           17       0.94      0.92      0.93      9108
#           18       0.93      0.90      0.92        31
#           19       0.97      0.98      0.98     29808
#           20       0.92      0.98      0.95     19343
#
#     accuracy                           0.99    600000
#    macro avg       0.81      0.73      0.75    600000
# weighted avg       0.99      0.99      0.98    600000
# '              precision    recall  f1-score   support\n\n           0       0.00      0.00      0.00        12\n           1       1.00      0.87      0.93       162\n           2       0.99      0.99      0.99    198477\n           3       1.00      1.00      1.00      1126\n           4       1.00      0.97      0.99       954\n           5       0.99      0.99      0.99    171544\n           6       0.99      0.99      0.99    141449\n           7       0.77      0.69      0.73       271\n           8       0.50      0.71      0.59       184\n           9       0.81      0.77      0.79       135\n          10       0.93      0.27      0.42       966\n          11       0.99      0.94      0.96     20974\n          12       0.56      0.50      0.53        10\n          13       0.87      0.76      0.81        17\n          14       0.00      0.00      0.00         2\n          15       0.89      0.77      0.83      5374\n          16       0.94      0.30      0.46        53\n          17       0.94      0.92      0.93      9108\n          18       0.93      0.90      0.92        31\n          19       0.97      0.98      0.98     29808\n          20       0.92      0.98      0.95     19343\n\n    accuracy                           0.99    600000\n   macro avg       0.81      0.73      0.75    600000\nweighted avg       0.99      0.99      0.98    600000\n'

# %%
# 테스트 데이터에 대해 predict 수행
# 모델 성능 - confusion matrix
from sklearn.metrics import accuracy_score
import numpy as np
# make predictions and evaluate
#neural
yhat = predict_stacked_model(stacked_model, x_test_1)
yhat_val = tf.argmax(yhat, axis=1)
acc = accuracy_score(y_test_1, yhat_val)
print('Stacked Test Accuracy: %.4f' % acc)

conf_mat = confusion_matrix(y_true=y_test_1, y_pred=yhat_val)
conf_mat

disp = ConfusionMatrixDisplay(conf_mat)
#disp = ConfusionMatrixDisplay(conf_mat)
disp.plot()
# Out:
# 18750/18750 - 29s - 29s/epoch - 2ms/step
# Stacked Test Accuracy: 0.9851

# %% [markdown]
# ### Merge 7

# %%
# load models from file
# for both logistic and nueral
def load_merge_models(n_models):
	all_models = list()

	for i in range(n_models):
		# define filename for this ensemble
#		colab_path = "gdrive/My Drive/Colab Notebooks/Network/models/"
		#model_4.save(colab_path + 'model4.h5')
		if i != 5 and i != 4: #Model4와 Binary 배제
			filename = colab_model_write_path + 'model1_' + str(i + 1) + '.h5'
			# load model from file
			model = load_model(filename,custom_objects=None)
			# add to list of members
			all_models.append(model)
			print('>loaded %s' % filename)
	return all_models

# %%
# load all models
#neural
from keras.models import load_model
n_members = 6
members = load_merge_models(n_members)
print('Loaded %d models' % len(members))


def define_stacked_model(members):
	initializer = tf.keras.initializers.GlorotUniform(seed=64)
	constraints = None

  # update all layers in all models to not be trainable
	for i in range(len(members)):
		model = members[i]
		for layer in model.layers:
			# make not trainable
			layer.trainable = False
			# rename to avoid 'unique layer name' issue
			layer._name = 'ensemble_' + str(i + 1) + '_' + layer.name


	# define multi-headed input
	ensemble_visible = [model.input for model in members]
	# concatenate merge output from each model
	ensemble_outputs = [model.output for model in members]
	merge = concatenate(ensemble_outputs)
	merge = Dense(128, kernel_initializer=initializer, activation='relu',name="dense_ea")(merge)
	merge = Dense(128, kernel_initializer=initializer, activation='relu',name="dense_eb")(merge)
	output = Dense(Y.shape[1], kernel_initializer=initializer, activation='softmax',name="dense_ec")(merge)
	model = Model(inputs=ensemble_visible, outputs=output)
	# plot graph of ensemble
	plot_model(model, show_shapes=True, to_file='model_graph.png')
	# compile
	model.summary()
	model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
	return model


def fit_stacked_model(model, inputX, inputy_enc):
	# prepare input data
	X = [inputX for _ in range(len(model.input))]
	# encode output data
#	inputy_enc = to_categorical(inputy)
	# fit model
	history_7=model.fit(X, inputy_enc, epochs=60, verbose=2,callbacks=[monitor_7])

stacked_model = define_stacked_model(members)

from keras.utils import to_categorical
fit_stacked_model(stacked_model, x_train,y_train)
stacked_model.save(colab_model_write_path + 'stacked_model_3M_merge7.h5')
# Out:
# >loaded /home/marius1406/202310120135/model1_1.h5
# >loaded /home/marius1406/202310120135/model1_2.h5
# >loaded /home/marius1406/202310120135/model1_3.h5
# >loaded /home/marius1406/202310120135/model1_4.h5
# Loaded 4 models
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  dense_2a_input (InputLayer)    [(None, 127)]        0           []
#
#  dense_3a_input (InputLayer)    [(None, 127)]        0           []
#
#  dense_4a_input (InputLayer)    [(None, 127)]        0           []
#
#  dense_1a_input (InputLayer)    [(None, 127)]        0           []
#
#  ensemble_2_dense_2a (Dense)    (None, 64)           8192        ['dense_2a_input[0][0]']
#
#  ensemble_3_dense_3a (Dense)    (None, 512)          65536       ['dense_3a_input[0][0]']
#
#  ensemble_4_dense_4a (Dense)    (None, 128)          16384       ['dense_4a_input[0][0]']
#
#  ensemble_1_dense_1a (Dense)    (None, 64)           8192        ['dense_1a_input[0][0]']
#
#  ensemble_2_dense_2b (Dense)    (None, 128)          8320        ['ensemble_2_dense_2a[0][0]']
#
#  ensemble_3_dropout_5 (Dropout)  (None, 512)         0           ['ensemble_3_dense_3a[0][0]']
#
#  ensemble_4_dropout_8 (Dropout)  (None, 128)         0           ['ensemble_4_dense_4a[0][0]']
#
#  ensemble_1_dense_1b (Dense)    (None, 128)          8320        ['ensemble_1_dense_1a[0][0]']
#
#  ensemble_2_dropout_2 (Dropout)  (None, 128)         0           ['ensemble_2_dense_2b[0][0]']
#
#  ensemble_3_dense_3b (Dense)    (None, 256)          131328      ['ensemble_3_dropout_5[0][0]']
#
#  ensemble_4_dense_4b (Dense)    (None, 64)           8256        ['ensemble_4_dropout_8[0][0]']
#
#  ensemble_1_dropout (Dropout)   (None, 128)          0           ['ensemble_1_dense_1b[0][0]']
#
#  ensemble_2_dense_2c (Dense)    (None, 256)          33024       ['ensemble_2_dropout_2[0][0]']
#
#  ensemble_3_dropout_6 (Dropout)  (None, 256)         0           ['ensemble_3_dense_3b[0][0]']
#
#  ensemble_4_dropout_9 (Dropout)  (None, 64)          0           ['ensemble_4_dense_4b[0][0]']
#
#  ensemble_1_dense_1c (Dense)    (None, 128)          16512       ['ensemble_1_dropout[0][0]']
#
#  ensemble_2_dropout_3 (Dropout)  (None, 256)         0           ['ensemble_2_dense_2c[0][0]']
#
#  ensemble_3_dense_3c (Dense)    (None, 128)          32896       ['ensemble_3_dropout_6[0][0]']
#
#  ensemble_4_dense_4c (Dense)    (None, 64)           4160        ['ensemble_4_dropout_9[0][0]']
#
#  ensemble_1_dropout_1 (Dropout)  (None, 128)         0           ['ensemble_1_dense_1c[0][0]']
#
#  ensemble_2_dense_2d (Dense)    (None, 128)          32896       ['ensemble_2_dropout_3[0][0]']
#
#  ensemble_3_dropout_7 (Dropout)  (None, 128)         0           ['ensemble_3_dense_3c[0][0]']
#
#  ensemble_4_dropout_10 (Dropout  (None, 64)          0           ['ensemble_4_dense_4c[0][0]']
#  )
#
#  ensemble_1_dense_1d (Dense)    (None, 64)           8256        ['ensemble_1_dropout_1[0][0]']
#
#  ensemble_2_dropout_4 (Dropout)  (None, 128)         0           ['ensemble_2_dense_2d[0][0]']
#
#  ensemble_3_dense_3d (Dense)    (None, 128)          16512       ['ensemble_3_dropout_7[0][0]']
#
#  ensemble_4_dense_4d (Dense)    (None, 128)          8320        ['ensemble_4_dropout_10[0][0]']
#
#  ensemble_1_dense (Dense)       (None, 21)           1365        ['ensemble_1_dense_1d[0][0]']
#
#  ensemble_2_dense_1 (Dense)     (None, 21)           2709        ['ensemble_2_dropout_4[0][0]']
#
#  ensemble_3_dense_2 (Dense)     (None, 21)           2709        ['ensemble_3_dense_3d[0][0]']
#
#  ensemble_4_dense_3 (Dense)     (None, 21)           2709        ['ensemble_4_dense_4d[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 84)           0           ['ensemble_1_dense[0][0]',
#                                                                   'ensemble_2_dense_1[0][0]',
#                                                                   'ensemble_3_dense_2[0][0]',
#                                                                   'ensemble_4_dense_3[0][0]']
#
#  dense_ea (Dense)               (None, 128)          10880       ['concatenate_1[0][0]']
#
#  dense_eb (Dense)               (None, 128)          16512       ['dense_ea[0][0]']
#
#  dense_ec (Dense)               (None, 21)           2709        ['dense_eb[0][0]']
#
# ==================================================================================================
# Total params: 446,697
# Trainable params: 30,101
# Non-trainable params: 416,596
# __________________________________________________________________________________________________
# Epoch 1/60
# 75000/75000 - 185s - loss: 0.0620 - accuracy: 0.9846 - 185s/epoch - 2ms/step
# Epoch 2/60
# 75000/75000 - 186s - loss: 0.0587 - accuracy: 0.9850 - 186s/epoch - 2ms/step
# Epoch 3/60
# 75000/75000 - 184s - loss: 0.0583 - accuracy: 0.9851 - 184s/epoch - 2ms/step
# Epoch 4/60
# 75000/75000 - 184s - loss: 0.0584 - accuracy: 0.9850 - 184s/epoch - 2ms/step
# Epoch 5/60
# 75000/75000 - 184s - loss: 0.0585 - accuracy: 0.9850 - 184s/epoch - 2ms/step
# Epoch 6/60
# 75000/75000 - 184s - loss: 0.0587 - accuracy: 0.9850 - 184s/epoch - 2ms/step
# Epoch 7/60
# 75000/75000 - 184s - loss: 0.0592 - accuracy: 0.9850 - 184s/epoch - 2ms/step
# Epoch 8/60
# 75000/75000 - 184s - loss: 0.0588 - accuracy: 0.9850 - 184s/epoch - 2ms/step
# Epoch 9/60
# 75000/75000 - 184s - loss: 0.0593 - accuracy: 0.9849 - 184s/epoch - 2ms/step
# Epoch 10/60
# 75000/75000 - 183s - loss: 0.0597 - accuracy: 0.9849 - 183s/epoch - 2ms/step
# Epoch 11/60
# 75000/75000 - 184s - loss: 0.0598 - accuracy: 0.9849 - 184s/epoch - 2ms/step
# Epoch 12/60
# 75000/75000 - 184s - loss: 0.0599 - accuracy: 0.9849 - 184s/epoch - 2ms/step
# Epoch 13/60
# 75000/75000 - 184s - loss: 0.0603 - accuracy: 0.9849 - 184s/epoch - 2ms/step
# Epoch 14/60
# 75000/75000 - 184s - loss: 0.0609 - accuracy: 0.9849 - 184s/epoch - 2ms/step
# Epoch 15/60
# 75000/75000 - 184s - loss: 0.0606 - accuracy: 0.9848 - 184s/epoch - 2ms/step
# Epoch 16/60
# 75000/75000 - 184s - loss: 0.0599 - accuracy: 0.9849 - 184s/epoch - 2ms/step
# Epoch 17/60
# 75000/75000 - 184s - loss: 0.0606 - accuracy: 0.9848 - 184s/epoch - 2ms/step
# Epoch 18/60
# 75000/75000 - 183s - loss: 0.0626 - accuracy: 0.9848 - 183s/epoch - 2ms/step
# Epoch 19/60
# 75000/75000 - 184s - loss: 0.0621 - accuracy: 0.9848 - 184s/epoch - 2ms/step
# Epoch 20/60
# 75000/75000 - 183s - loss: 0.0611 - accuracy: 0.9848 - 183s/epoch - 2ms/step
# Epoch 21/60
# 75000/75000 - 184s - loss: 0.0611 - accuracy: 0.9848 - 184s/epoch - 2ms/step
# Epoch 22/60
# 75000/75000 - 184s - loss: 0.0617 - accuracy: 0.9848 - 184s/epoch - 2ms/step
# Epoch 23/60
# 75000/75000 - 184s - loss: 0.0628 - accuracy: 0.9847 - 184s/epoch - 2ms/step
# Epoch 24/60
# 75000/75000 - 183s - loss: 0.0621 - accuracy: 0.9848 - 183s/epoch - 2ms/step
# Epoch 25/60
# 75000/75000 - 183s - loss: 0.0625 - accuracy: 0.9848 - 183s/epoch - 2ms/step
# Epoch 26/60
# 75000/75000 - 183s - loss: 0.0619 - accuracy: 0.9847 - 183s/epoch - 2ms/step
# Epoch 27/60
# 75000/75000 - 183s - loss: 0.0631 - accuracy: 0.9847 - 183s/epoch - 2ms/step
# Epoch 28/60
# 75000/75000 - 184s - loss: 0.0633 - accuracy: 0.9847 - 184s/epoch - 2ms/step
# Epoch 29/60
# 75000/75000 - 184s - loss: 0.0638 - accuracy: 0.9847 - 184s/epoch - 2ms/step
# Epoch 30/60
# 75000/75000 - 184s - loss: 0.0645 - accuracy: 0.9847 - 184s/epoch - 2ms/step
# Epoch 31/60
# 75000/75000 - 183s - loss: 0.0642 - accuracy: 0.9846 - 183s/epoch - 2ms/step
# Epoch 32/60
# 75000/75000 - 184s - loss: 0.0656 - accuracy: 0.9846 - 184s/epoch - 2ms/step
# Epoch 33/60
# 75000/75000 - 182s - loss: 0.0678 - accuracy: 0.9846 - 182s/epoch - 2ms/step
# Epoch 34/60
# 75000/75000 - 184s - loss: 0.0654 - accuracy: 0.9846 - 184s/epoch - 2ms/step
# Epoch 35/60
# 75000/75000 - 184s - loss: 0.0653 - accuracy: 0.9846 - 184s/epoch - 2ms/step
# Epoch 36/60
# 75000/75000 - 182s - loss: 0.0674 - accuracy: 0.9845 - 182s/epoch - 2ms/step
# Epoch 37/60
# 75000/75000 - 184s - loss: 0.0693 - accuracy: 0.9846 - 184s/epoch - 2ms/step
# Epoch 38/60
# 75000/75000 - 183s - loss: 0.0683 - accuracy: 0.9845 - 183s/epoch - 2ms/step
# Epoch 39/60
# 75000/75000 - 184s - loss: 0.0704 - accuracy: 0.9845 - 184s/epoch - 2ms/step
# Epoch 40/60
# 75000/75000 - 184s - loss: 0.0666 - accuracy: 0.9845 - 184s/epoch - 2ms/step
# Epoch 41/60
# 75000/75000 - 184s - loss: 0.0682 - accuracy: 0.9845 - 184s/epoch - 2ms/step
# Epoch 42/60
# 75000/75000 - 186s - loss: 0.0679 - accuracy: 0.9844 - 186s/epoch - 2ms/step
# Epoch 43/60
# 75000/75000 - 184s - loss: 0.0693 - accuracy: 0.9844 - 184s/epoch - 2ms/step
# Epoch 44/60
# 75000/75000 - 184s - loss: 0.0669 - accuracy: 0.9845 - 184s/epoch - 2ms/step
# Epoch 45/60
# 75000/75000 - 183s - loss: 0.0674 - accuracy: 0.9845 - 183s/epoch - 2ms/step
# Epoch 46/60
# 75000/75000 - 184s - loss: 0.0684 - accuracy: 0.9845 - 184s/epoch - 2ms/step
# Epoch 47/60
# 75000/75000 - 184s - loss: 0.0713 - accuracy: 0.9845 - 184s/epoch - 2ms/step
# Epoch 48/60
# 75000/75000 - 184s - loss: 0.0705 - accuracy: 0.9845 - 184s/epoch - 2ms/step
# Epoch 49/60
# 75000/75000 - 183s - loss: 0.0692 - accuracy: 0.9845 - 183s/epoch - 2ms/step
# Epoch 50/60
# 75000/75000 - 184s - loss: 0.0651 - accuracy: 0.9845 - 184s/epoch - 2ms/step
# Epoch 51/60
# 75000/75000 - 184s - loss: 0.0746 - accuracy: 0.9845 - 184s/epoch - 2ms/step
# Epoch 52/60
# 75000/75000 - 183s - loss: 0.0681 - accuracy: 0.9845 - 183s/epoch - 2ms/step
# Epoch 53/60
# 75000/75000 - 184s - loss: 0.0673 - accuracy: 0.9844 - 184s/epoch - 2ms/step
# Epoch 54/60
# 75000/75000 - 183s - loss: 0.0690 - accuracy: 0.9844 - 183s/epoch - 2ms/step
# Epoch 55/60
# 75000/75000 - 184s - loss: 0.0694 - accuracy: 0.9843 - 184s/epoch - 2ms/step
# Epoch 56/60
# 75000/75000 - 184s - loss: 0.0724 - accuracy: 0.9844 - 184s/epoch - 2ms/step
# Epoch 57/60
# 75000/75000 - 184s - loss: 0.0700 - accuracy: 0.9844 - 184s/epoch - 2ms/step
# Epoch 58/60
# 75000/75000 - 183s - loss: 0.0675 - accuracy: 0.9844 - 183s/epoch - 2ms/step
# Epoch 59/60
# 75000/75000 - 184s - loss: 0.0703 - accuracy: 0.9844 - 184s/epoch - 2ms/step
# Epoch 60/60
# 75000/75000 - 183s - loss: 0.0689 - accuracy: 0.9845 - 183s/epoch - 2ms/step

# %%
from sklearn.metrics import accuracy_score
import numpy as np
# make predictions and evaluate
#neural
yhat = predict_stacked_model(stacked_model, x_test_1)
yhat_val = tf.argmax(yhat, axis=1)
acc = accuracy_score(y_test_1, yhat_val)
print('Stacked Test Accuracy: %.4f' % acc)
# Out:
# 18750/18750 - 29s - 29s/epoch - 2ms/step
# Stacked Test Accuracy: 0.9803

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test_1, yhat_val))
classification_report(y_test_1, yhat_val)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        12
#            1       1.00      0.87      0.93       162
#            2       0.97      1.00      0.99    198477
#            3       1.00      1.00      1.00      1126
#            4       1.00      0.97      0.99       954
#            5       0.99      0.99      0.99    171544
#            6       0.99      0.99      0.99    141449
#            7       0.42      0.92      0.58       271
#            8       0.45      0.21      0.28       184
#            9       0.99      0.73      0.84       135
#           10       1.00      0.24      0.38       966
#           11       0.98      0.94      0.96     20974
#           12       0.67      0.40      0.50        10
#           13       0.73      0.94      0.82        17
#           14       0.00      0.00      0.00         2
#           15       0.89      0.77      0.82      5374
#           16       1.00      0.30      0.46        53
#           17       0.98      0.82      0.89      9108
#           18       1.00      0.84      0.91        31
#           19       0.99      0.94      0.96     29808
#           20       0.90      0.99      0.95     19343
#
#     accuracy                           0.98    600000
#    macro avg       0.81      0.71      0.73    600000
# weighted avg       0.98      0.98      0.98    600000
# '              precision    recall  f1-score   support\n\n           0       0.00      0.00      0.00        12\n           1       1.00      0.87      0.93       162\n           2       0.97      1.00      0.99    198477\n           3       1.00      1.00      1.00      1126\n           4       1.00      0.97      0.99       954\n           5       0.99      0.99      0.99    171544\n           6       0.99      0.99      0.99    141449\n           7       0.42      0.92      0.58       271\n           8       0.45      0.21      0.28       184\n           9       0.99      0.73      0.84       135\n          10       1.00      0.24      0.38       966\n          11       0.98      0.94      0.96     20974\n          12       0.67      0.40      0.50        10\n          13       0.73      0.94      0.82        17\n          14       0.00      0.00      0.00         2\n          15       0.89      0.77      0.82      5374\n          16       1.00      0.30      0.46        53\n          17       0.98      0.82      0.89      9108\n          18       1.00      0.84      0.91        31\n          19       0.99      0.94      0.96     29808\n          20       0.90      0.99      0.95     19343\n\n    accuracy                           0.98    600000\n   macro avg       0.81      0.71      0.73    600000\nweighted avg       0.98      0.98      0.98    600000\n'

# %%
# 테스트 데이터에 대해 predict 수행
# 모델 성능 - confusion matrix
from sklearn.metrics import accuracy_score
import numpy as np
# make predictions and evaluate
#neural
yhat = predict_stacked_model(stacked_model, x_test_1)
yhat_val = tf.argmax(yhat, axis=1)
acc = accuracy_score(y_test_1, yhat_val)
print('Stacked Test Accuracy: %.4f' % acc)

conf_mat = confusion_matrix(y_true=y_test_1, y_pred=yhat_val)
conf_mat

disp = ConfusionMatrixDisplay(conf_mat)
#disp = ConfusionMatrixDisplay(conf_mat)
disp.plot()
# Out:
# 18750/18750 - 26s - 26s/epoch - 1ms/step
# Stacked Test Accuracy: 0.9803

# %% [markdown]
# ### BM 7

# %%
# load models from file
# for both logistic and nueral
def load_BM_models(n_models):
	all_models = list()

	for i in range(n_models):
		# define filename for this ensemble
#		colab_path = "gdrive/My Drive/Colab Notebooks/Network/models/"
		#model_4.save(colab_path + 'model4.h5')
		if i != 5 and i != 3: #Model4와 Binary 배제
			filename = colab_model_write_path + 'model1_' + str(i + 1) + '.h5'
			# load model from file
			model = load_model(filename,custom_objects=None)
			# add to list of members
			all_models.append(model)
			print('>loaded %s' % filename)
	return all_models

# %%
# load all models
#neural
from keras.models import load_model
n_members = 6
members = load_merge_models(n_members)
print('Loaded %d models' % len(members))


def define_stacked_model(members):
	initializer = tf.keras.initializers.GlorotUniform(seed=64)
	constraints = None

  # update all layers in all models to not be trainable
	for i in range(len(members)):
		model = members[i]
		for layer in model.layers:
			# make not trainable
			layer.trainable = False
			# rename to avoid 'unique layer name' issue
			layer._name = 'ensemble_' + str(i + 1) + '_' + layer.name


	# define multi-headed input
	ensemble_visible = [model.input for model in members]
	# concatenate merge output from each model
	ensemble_outputs = [model.output for model in members]
	merge = concatenate(ensemble_outputs)
	merge = Dense(128, kernel_initializer=initializer, activation='relu',name="dense_ea")(merge)
	merge = Dense(128, kernel_initializer=initializer, activation='relu',name="dense_eb")(merge)
	output = Dense(Y.shape[1], kernel_initializer=initializer, activation='softmax',name="dense_ec")(merge)
	model = Model(inputs=ensemble_visible, outputs=output)
	# plot graph of ensemble
	plot_model(model, show_shapes=True, to_file='model_graph.png')
	# compile
	model.summary()
	model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
	return model


def fit_stacked_model(model, inputX, inputy_enc):
	# prepare input data
	X = [inputX for _ in range(len(model.input))]
	# encode output data
#	inputy_enc = to_categorical(inputy)
	# fit model
	history_7=model.fit(X, inputy_enc, epochs=60, verbose=2,callbacks=[monitor_7])


stacked_model = define_stacked_model(members)

from keras.utils import to_categorical
fit_stacked_model(stacked_model, x_train,y_train)
stacked_model.save(colab_model_write_path + 'stacked_model_3M_BM7.h5')
# Out:
# >loaded /home/marius1406/202310120135/model1_1.h5
# >loaded /home/marius1406/202310120135/model1_2.h5
# >loaded /home/marius1406/202310120135/model1_3.h5
# >loaded /home/marius1406/202310120135/model1_4.h5
# Loaded 4 models
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  dense_2a_input (InputLayer)    [(None, 127)]        0           []
#
#  dense_3a_input (InputLayer)    [(None, 127)]        0           []
#
#  dense_4a_input (InputLayer)    [(None, 127)]        0           []
#
#  dense_1a_input (InputLayer)    [(None, 127)]        0           []
#
#  ensemble_2_dense_2a (Dense)    (None, 64)           8192        ['dense_2a_input[0][0]']
#
#  ensemble_3_dense_3a (Dense)    (None, 512)          65536       ['dense_3a_input[0][0]']
#
#  ensemble_4_dense_4a (Dense)    (None, 128)          16384       ['dense_4a_input[0][0]']
#
#  ensemble_1_dense_1a (Dense)    (None, 64)           8192        ['dense_1a_input[0][0]']
#
#  ensemble_2_dense_2b (Dense)    (None, 128)          8320        ['ensemble_2_dense_2a[0][0]']
#
#  ensemble_3_dropout_5 (Dropout)  (None, 512)         0           ['ensemble_3_dense_3a[0][0]']
#
#  ensemble_4_dropout_8 (Dropout)  (None, 128)         0           ['ensemble_4_dense_4a[0][0]']
#
#  ensemble_1_dense_1b (Dense)    (None, 128)          8320        ['ensemble_1_dense_1a[0][0]']
#
#  ensemble_2_dropout_2 (Dropout)  (None, 128)         0           ['ensemble_2_dense_2b[0][0]']
#
#  ensemble_3_dense_3b (Dense)    (None, 256)          131328      ['ensemble_3_dropout_5[0][0]']
#
#  ensemble_4_dense_4b (Dense)    (None, 64)           8256        ['ensemble_4_dropout_8[0][0]']
#
#  ensemble_1_dropout (Dropout)   (None, 128)          0           ['ensemble_1_dense_1b[0][0]']
#
#  ensemble_2_dense_2c (Dense)    (None, 256)          33024       ['ensemble_2_dropout_2[0][0]']
#
#  ensemble_3_dropout_6 (Dropout)  (None, 256)         0           ['ensemble_3_dense_3b[0][0]']
#
#  ensemble_4_dropout_9 (Dropout)  (None, 64)          0           ['ensemble_4_dense_4b[0][0]']
#
#  ensemble_1_dense_1c (Dense)    (None, 128)          16512       ['ensemble_1_dropout[0][0]']
#
#  ensemble_2_dropout_3 (Dropout)  (None, 256)         0           ['ensemble_2_dense_2c[0][0]']
#
#  ensemble_3_dense_3c (Dense)    (None, 128)          32896       ['ensemble_3_dropout_6[0][0]']
#
#  ensemble_4_dense_4c (Dense)    (None, 64)           4160        ['ensemble_4_dropout_9[0][0]']
#
#  ensemble_1_dropout_1 (Dropout)  (None, 128)         0           ['ensemble_1_dense_1c[0][0]']
#
#  ensemble_2_dense_2d (Dense)    (None, 128)          32896       ['ensemble_2_dropout_3[0][0]']
#
#  ensemble_3_dropout_7 (Dropout)  (None, 128)         0           ['ensemble_3_dense_3c[0][0]']
#
#  ensemble_4_dropout_10 (Dropout  (None, 64)          0           ['ensemble_4_dense_4c[0][0]']
#  )
#
#  ensemble_1_dense_1d (Dense)    (None, 64)           8256        ['ensemble_1_dropout_1[0][0]']
#
#  ensemble_2_dropout_4 (Dropout)  (None, 128)         0           ['ensemble_2_dense_2d[0][0]']
#
#  ensemble_3_dense_3d (Dense)    (None, 128)          16512       ['ensemble_3_dropout_7[0][0]']
#
#  ensemble_4_dense_4d (Dense)    (None, 128)          8320        ['ensemble_4_dropout_10[0][0]']
#
#  ensemble_1_dense (Dense)       (None, 21)           1365        ['ensemble_1_dense_1d[0][0]']
#
#  ensemble_2_dense_1 (Dense)     (None, 21)           2709        ['ensemble_2_dropout_4[0][0]']
#
#  ensemble_3_dense_2 (Dense)     (None, 21)           2709        ['ensemble_3_dense_3d[0][0]']
#
#  ensemble_4_dense_3 (Dense)     (None, 21)           2709        ['ensemble_4_dense_4d[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 84)           0           ['ensemble_1_dense[0][0]',
#                                                                   'ensemble_2_dense_1[0][0]',
#                                                                   'ensemble_3_dense_2[0][0]',
#                                                                   'ensemble_4_dense_3[0][0]']
#
#  dense_ea (Dense)               (None, 128)          10880       ['concatenate_2[0][0]']
#
#  dense_eb (Dense)               (None, 128)          16512       ['dense_ea[0][0]']
#
#  dense_ec (Dense)               (None, 21)           2709        ['dense_eb[0][0]']
#
# ==================================================================================================
# Total params: 446,697
# Trainable params: 30,101
# Non-trainable params: 416,596
# __________________________________________________________________________________________________
# Epoch 1/60
# 75000/75000 - 185s - loss: 0.0621 - accuracy: 0.9846 - 185s/epoch - 2ms/step
# Epoch 2/60
# 75000/75000 - 183s - loss: 0.0588 - accuracy: 0.9849 - 183s/epoch - 2ms/step
# Epoch 3/60
# 75000/75000 - 184s - loss: 0.0587 - accuracy: 0.9850 - 184s/epoch - 2ms/step
# Epoch 4/60
# 75000/75000 - 184s - loss: 0.0588 - accuracy: 0.9850 - 184s/epoch - 2ms/step
# Epoch 5/60
# 75000/75000 - 183s - loss: 0.0588 - accuracy: 0.9850 - 183s/epoch - 2ms/step
# Epoch 6/60
# 75000/75000 - 184s - loss: 0.0587 - accuracy: 0.9850 - 184s/epoch - 2ms/step
# Epoch 7/60
# 75000/75000 - 184s - loss: 0.0593 - accuracy: 0.9849 - 184s/epoch - 2ms/step
# Epoch 8/60
# 75000/75000 - 184s - loss: 0.0593 - accuracy: 0.9849 - 184s/epoch - 2ms/step
# Epoch 9/60
# 75000/75000 - 185s - loss: 0.0604 - accuracy: 0.9849 - 185s/epoch - 2ms/step
# Epoch 10/60
# 75000/75000 - 185s - loss: 0.0598 - accuracy: 0.9848 - 185s/epoch - 2ms/step
# Epoch 11/60
# 75000/75000 - 184s - loss: 0.0600 - accuracy: 0.9849 - 184s/epoch - 2ms/step
# Epoch 12/60
# 75000/75000 - 184s - loss: 0.0602 - accuracy: 0.9849 - 184s/epoch - 2ms/step
# Epoch 13/60
# 75000/75000 - 184s - loss: 0.0607 - accuracy: 0.9848 - 184s/epoch - 2ms/step
# Epoch 14/60
# 75000/75000 - 184s - loss: 0.0601 - accuracy: 0.9847 - 184s/epoch - 2ms/step
# Epoch 15/60
# 75000/75000 - 185s - loss: 0.0605 - accuracy: 0.9847 - 185s/epoch - 2ms/step
# Epoch 16/60
# 75000/75000 - 184s - loss: 0.0608 - accuracy: 0.9847 - 184s/epoch - 2ms/step
# Epoch 17/60
# 75000/75000 - 185s - loss: 0.0611 - accuracy: 0.9848 - 185s/epoch - 2ms/step
# Epoch 18/60
# 75000/75000 - 185s - loss: 0.0642 - accuracy: 0.9847 - 185s/epoch - 2ms/step
# Epoch 19/60
# 75000/75000 - 184s - loss: 0.0622 - accuracy: 0.9847 - 184s/epoch - 2ms/step
# Epoch 20/60
# 75000/75000 - 185s - loss: 0.0621 - accuracy: 0.9848 - 185s/epoch - 2ms/step
# Epoch 21/60
# 75000/75000 - 183s - loss: 0.0641 - accuracy: 0.9847 - 183s/epoch - 2ms/step
# Epoch 22/60
# 75000/75000 - 183s - loss: 0.0632 - accuracy: 0.9846 - 183s/epoch - 2ms/step
# Epoch 23/60
# 75000/75000 - 184s - loss: 0.0657 - accuracy: 0.9846 - 184s/epoch - 2ms/step
# Epoch 24/60
# 75000/75000 - 184s - loss: 0.0686 - accuracy: 0.9847 - 184s/epoch - 2ms/step
# Epoch 25/60
# 75000/75000 - 185s - loss: 0.0657 - accuracy: 0.9846 - 185s/epoch - 2ms/step
# Epoch 26/60
# 75000/75000 - 183s - loss: 0.0648 - accuracy: 0.9846 - 183s/epoch - 2ms/step
# Epoch 27/60
# 75000/75000 - 184s - loss: 0.0657 - accuracy: 0.9845 - 184s/epoch - 2ms/step
# Epoch 28/60
# 75000/75000 - 185s - loss: 0.0678 - accuracy: 0.9846 - 185s/epoch - 2ms/step
# Epoch 29/60
# 75000/75000 - 183s - loss: 0.0655 - accuracy: 0.9845 - 183s/epoch - 2ms/step
# Epoch 30/60
# 75000/75000 - 184s - loss: 0.0668 - accuracy: 0.9846 - 184s/epoch - 2ms/step
# Epoch 31/60
# 75000/75000 - 184s - loss: 0.0712 - accuracy: 0.9845 - 184s/epoch - 2ms/step
# Epoch 32/60
# 75000/75000 - 184s - loss: 0.0664 - accuracy: 0.9844 - 184s/epoch - 2ms/step
# Epoch 33/60
# 75000/75000 - 185s - loss: 0.0675 - accuracy: 0.9845 - 185s/epoch - 2ms/step
# Epoch 34/60
# 75000/75000 - 184s - loss: 0.0658 - accuracy: 0.9843 - 184s/epoch - 2ms/step
# Epoch 35/60
# 75000/75000 - 184s - loss: 0.0690 - accuracy: 0.9844 - 184s/epoch - 2ms/step
# Epoch 36/60
# 75000/75000 - 183s - loss: 0.0683 - accuracy: 0.9843 - 183s/epoch - 2ms/step
# Epoch 37/60
# 75000/75000 - 184s - loss: 0.0677 - accuracy: 0.9844 - 184s/epoch - 2ms/step
# Epoch 38/60
# 75000/75000 - 185s - loss: 0.0688 - accuracy: 0.9844 - 185s/epoch - 2ms/step
# Epoch 39/60
# 75000/75000 - 184s - loss: 0.0740 - accuracy: 0.9843 - 184s/epoch - 2ms/step
# Epoch 40/60
# 75000/75000 - 184s - loss: 0.0684 - accuracy: 0.9843 - 184s/epoch - 2ms/step
# Epoch 41/60
# 75000/75000 - 183s - loss: 0.0643 - accuracy: 0.9846 - 183s/epoch - 2ms/step
# Epoch 42/60
# 75000/75000 - 184s - loss: 0.0666 - accuracy: 0.9845 - 184s/epoch - 2ms/step
# Epoch 43/60
# 75000/75000 - 183s - loss: 0.0636 - accuracy: 0.9846 - 183s/epoch - 2ms/step
# Epoch 44/60
# 75000/75000 - 184s - loss: 0.0663 - accuracy: 0.9847 - 184s/epoch - 2ms/step
# Epoch 45/60
# 75000/75000 - 184s - loss: 0.0680 - accuracy: 0.9846 - 184s/epoch - 2ms/step
# Epoch 46/60
# 75000/75000 - 183s - loss: 0.0677 - accuracy: 0.9847 - 183s/epoch - 2ms/step
# Epoch 47/60
# 75000/75000 - 184s - loss: 0.0689 - accuracy: 0.9847 - 184s/epoch - 2ms/step
# Epoch 48/60
# 75000/75000 - 184s - loss: 0.0679 - accuracy: 0.9847 - 184s/epoch - 2ms/step
# Epoch 49/60
# 75000/75000 - 183s - loss: 0.0646 - accuracy: 0.9847 - 183s/epoch - 2ms/step
# Epoch 50/60
# 75000/75000 - 185s - loss: 0.0686 - accuracy: 0.9847 - 185s/epoch - 2ms/step
# Epoch 51/60
# 75000/75000 - 184s - loss: 0.0679 - accuracy: 0.9847 - 184s/epoch - 2ms/step
# Epoch 52/60
# 75000/75000 - 184s - loss: 0.0753 - accuracy: 0.9846 - 184s/epoch - 2ms/step
# Epoch 53/60
# 75000/75000 - 184s - loss: 0.0670 - accuracy: 0.9846 - 184s/epoch - 2ms/step
# Epoch 54/60
# 75000/75000 - 185s - loss: 0.0718 - accuracy: 0.9846 - 185s/epoch - 2ms/step
# Epoch 55/60
# 75000/75000 - 184s - loss: 0.0725 - accuracy: 0.9845 - 184s/epoch - 2ms/step
# Epoch 56/60
# 75000/75000 - 183s - loss: 0.0687 - accuracy: 0.9845 - 183s/epoch - 2ms/step
# Epoch 57/60
# 75000/75000 - 184s - loss: 0.0702 - accuracy: 0.9845 - 184s/epoch - 2ms/step
# Epoch 58/60
# 75000/75000 - 184s - loss: 0.0698 - accuracy: 0.9846 - 184s/epoch - 2ms/step
# Epoch 59/60
# 75000/75000 - 184s - loss: 0.0668 - accuracy: 0.9846 - 184s/epoch - 2ms/step
# Epoch 60/60
# 75000/75000 - 186s - loss: 0.0693 - accuracy: 0.9846 - 186s/epoch - 2ms/step

# %%
from sklearn.metrics import accuracy_score
import numpy as np
# make predictions and evaluate
#neural
yhat = predict_stacked_model(stacked_model, x_test_1)
yhat_val = tf.argmax(yhat, axis=1)
acc = accuracy_score(y_test_1, yhat_val)
print('Stacked Test Accuracy: %.4f' % acc)
# Out:
# 18750/18750 - 28s - 28s/epoch - 2ms/step
# Stacked Test Accuracy: 0.9838

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test_1, yhat_val))
classification_report(y_test_1, yhat_val)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        12
#            1       1.00      0.87      0.93       162
#            2       0.99      1.00      0.99    198477
#            3       1.00      1.00      1.00      1126
#            4       1.00      0.97      0.99       954
#            5       0.99      0.99      0.99    171544
#            6       0.98      0.99      0.99    141449
#            7       0.88      0.54      0.67       271
#            8       0.34      0.97      0.50       184
#            9       0.99      0.73      0.84       135
#           10       0.97      0.24      0.39       966
#           11       0.99      0.95      0.96     20974
#           12       0.00      0.00      0.00        10
#           13       0.81      0.76      0.79        17
#           14       0.00      0.00      0.00         2
#           15       0.88      0.76      0.82      5374
#           16       1.00      0.30      0.46        53
#           17       0.92      0.94      0.93      9108
#           18       1.00      0.87      0.93        31
#           19       0.99      0.93      0.96     29808
#           20       0.94      0.97      0.95     19343
#
#     accuracy                           0.98    600000
#    macro avg       0.79      0.70      0.72    600000
# weighted avg       0.98      0.98      0.98    600000
# '              precision    recall  f1-score   support\n\n           0       0.00      0.00      0.00        12\n           1       1.00      0.87      0.93       162\n           2       0.99      1.00      0.99    198477\n           3       1.00      1.00      1.00      1126\n           4       1.00      0.97      0.99       954\n           5       0.99      0.99      0.99    171544\n           6       0.98      0.99      0.99    141449\n           7       0.88      0.54      0.67       271\n           8       0.34      0.97      0.50       184\n           9       0.99      0.73      0.84       135\n          10       0.97      0.24      0.39       966\n          11       0.99      0.95      0.96     20974\n          12       0.00      0.00      0.00        10\n          13       0.81      0.76      0.79        17\n          14       0.00      0.00      0.00         2\n          15       0.88      0.76      0.82      5374\n          16       1.00      0.30      0.46        53\n          17       0.92      0.94      0.93      9108\n          18       1.00      0.87      0.93        31\n          19       0.99      0.93      0.96     29808\n          20       0.94      0.97      0.95     19343\n\n    accuracy                           0.98    600000\n   macro avg       0.79      0.70      0.72    600000\nweighted avg       0.98      0.98      0.98    600000\n'

# %%
# 테스트 데이터에 대해 predict 수행
# 모델 성능 - confusion matrix
from sklearn.metrics import accuracy_score
import numpy as np
# make predictions and evaluate
#neural
yhat = predict_stacked_model(stacked_model, x_test_1)
yhat_val = tf.argmax(yhat, axis=1)
acc = accuracy_score(y_test_1, yhat_val)
print('Stacked Test Accuracy: %.4f' % acc)

conf_mat = confusion_matrix(y_true=y_test_1, y_pred=yhat_val)
conf_mat

disp = ConfusionMatrixDisplay(conf_mat)
#disp = ConfusionMatrixDisplay(conf_mat)
disp.plot()
# Out:
# 18750/18750 - 27s - 27s/epoch - 1ms/step
# Stacked Test Accuracy: 0.9838
